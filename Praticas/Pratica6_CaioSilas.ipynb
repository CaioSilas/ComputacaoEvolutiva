# %%
! pip install deap
# Out:
# Requirement already satisfied: deap in /usr/local/lib/python3.11/dist-packages (1.4.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from deap) (1.26.4)

# %%
import random
import numpy as np
from deap import base, creator, tools, algorithms

# %%
# Definição do problema: Bin Packing
N_ITENS = 50  # Número de itens
CAPACIDADE_BIN = 100  # Capacidade máxima de cada caixa

# Gerar pesos dos itens aleatórios (entre 10 e 50)
np.random.seed(42)
pesos_itens = np.random.randint(10, 50, size=N_ITENS)
print(f"Pesos dos itens: {pesos_itens}")
print(f"Capacidade de cada bin: {CAPACIDADE_BIN}")
# Out:
# Pesos dos itens: [48 38 24 17 30 48 28 32 20 20 33 45 49 33 12 31 11 33 39 47 11 30 42 21
#  31 34 36 37 25 24 12 46 16 30 18 48 27 13 34 23 18 35 11 29 37 16 17 44
#  23 26]
# Capacidade de cada bin: 100

# %%
def avaliar(individuo):
    """Calcula o número de bins usados."""
    bins = {}  # Dicionário para armazenar os bins e seus pesos
    for i, bin_index in enumerate(individuo):
        if bin_index not in bins:
            bins[bin_index] = 0
        bins[bin_index] += pesos_itens[i]

    # Penalizar bins que excedem a capacidade
    num_bins = len(bins)
    for peso in bins.values():
        if peso > CAPACIDADE_BIN:
            num_bins += 10  # Penalidade alta para bins inválidos

    return num_bins,

# %%
# Criar classes para fitness e indivíduo
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))  # Minimizar número de bins
creator.create("Individual", list, fitness=creator.FitnessMin)

# Inicializar a toolbox DEAP
toolbox = base.Toolbox()
toolbox.register("genes", random.randint, 0, N_ITENS)  # Genes representam o bin de cada item
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.genes, n=N_ITENS)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

toolbox.register("evaluate", avaliar)
toolbox.register("mate", tools.cxTwoPoint)  # Cruzamento de dois pontos
toolbox.register("mutate", tools.mutUniformInt, low=0, up=N_ITENS, indpb=0.1)  # Mutação
toolbox.register("select", tools.selTournament, tournsize=3)  # Seleção por torneio
# Out:
# /usr/local/lib/python3.11/dist-packages/deap/creator.py:185: RuntimeWarning: A class named 'FitnessMin' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# /usr/local/lib/python3.11/dist-packages/deap/creator.py:185: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "

# %%
def busca_local(individuo):
    """Busca local: remove e reinsire um item aleatoriamente."""
    for i in range(N_ITENS):
        # Escolhe um item aleatoriamente
        item_index = random.randint(0, N_ITENS - 1)

        # Tenta movê-lo para um bin diferente
        novo_bin = random.randint(0, N_ITENS)

        # Cria um novo indivíduo com a mudança
        novo_individuo = individuo[:]
        novo_individuo[item_index] = novo_bin

        # Se a nova solução for melhor, substitui a antiga
        if avaliar(novo_individuo) < avaliar(individuo):
            individuo[:] = novo_individuo[:]
            break  # Sai do loop se encontrar uma solução melhor

    return individuo,

# %%
toolbox.register("busca_local", busca_local)

# %%
def algoritmo_memetico(pop_size=100, ngen=100, p_cx=0.7, p_mut=0.2, p_local=0.3):
    """Executa um Algoritmo Memético com GA + Busca Local."""
    pop = toolbox.population(n=pop_size)
    hof = tools.HallOfFame(1)
    stats = tools.Statistics(lambda ind: ind.fitness.values)
    stats.register("min", np.min)
    stats.register("avg", np.mean)

    for gen in range(ngen):
        # Seleção e reprodução
        offspring = toolbox.select(pop, len(pop))
        offspring = list(map(toolbox.clone, offspring))

        for child1, child2 in zip(offspring[::2], offspring[1::2]):
            if random.random() < p_cx:
                toolbox.mate(child1, child2)
                del child1.fitness.values, child2.fitness.values

        for mutant in offspring:
            if random.random() < p_mut:
                toolbox.mutate(mutant)
                del mutant.fitness.values

        # Reavaliação dos filhos
        for ind in offspring:
            if not ind.fitness.valid:
                ind.fitness.values = toolbox.evaluate(ind)

        # Aplicação da busca local a uma fração da população
        for ind in random.sample(offspring, int(p_local * len(offspring))):
           toolbox.busca_local(ind)
           ind.fitness.values = toolbox.evaluate(ind)

        pop[:] = offspring
        hof.update(pop)

        # Coleta estatísticas
        record = stats.compile(pop)
        print(f"Geração {gen}: Min = {record['min']}, Avg = {record['avg']}")

    return pop, hof

# %%
resultados = []
for i in range(10):
    pop, hof = algoritmo_memetico(pop_size=100, ngen=100, p_cx=0.7, p_mut=0.2, p_local=0.3)
    resultados.append(avaliar(hof[0])[0])  # Armazenar o número de bins


media_resultados = np.mean(resultados)
print("Média do número de bins:", media_resultados)
# Melhor solução encontrada
print("Melhor solução:", hof[0])
print("Valor total:", avaliar(hof[0])[0])
peso_total = 0
for bin_index in range(N_ITENS + 1): # Considerando todos os bins possíveis
    peso_bin = sum(pesos_itens[i] for i in range(N_ITENS) if hof[0][i] == bin_index)
    peso_total += peso_bin

print("Peso total:", peso_total)
print("tamanho da Solução:",len(hof[0]))
# Out:
# Geração 0: Min = 29.0, Avg = 43.73
# Geração 1: Min = 28.0, Avg = 40.55
# Geração 2: Min = 29.0, Avg = 37.73
# Geração 3: Min = 28.0, Avg = 37.89
# Geração 4: Min = 27.0, Avg = 37.3
# Geração 5: Min = 25.0, Avg = 35.15
# Geração 6: Min = 27.0, Avg = 35.39
# Geração 7: Min = 27.0, Avg = 35.73
# Geração 8: Min = 25.0, Avg = 35.68
# Geração 9: Min = 24.0, Avg = 33.75
# Geração 10: Min = 23.0, Avg = 34.52
# Geração 11: Min = 23.0, Avg = 36.05
# Geração 12: Min = 23.0, Avg = 34.93
# Geração 13: Min = 23.0, Avg = 32.67
# Geração 14: Min = 22.0, Avg = 31.79
# Geração 15: Min = 22.0, Avg = 30.95
# Geração 16: Min = 22.0, Avg = 29.26
# Geração 17: Min = 21.0, Avg = 26.67
# Geração 18: Min = 20.0, Avg = 24.68
# Geração 19: Min = 20.0, Avg = 24.06
# Geração 20: Min = 20.0, Avg = 23.87
# Geração 21: Min = 20.0, Avg = 22.61
# Geração 22: Min = 19.0, Avg = 22.8
# Geração 23: Min = 20.0, Avg = 23.66
# Geração 24: Min = 20.0, Avg = 22.61
# Geração 25: Min = 20.0, Avg = 21.95
# Geração 26: Min = 19.0, Avg = 22.35
# Geração 27: Min = 19.0, Avg = 21.6
# Geração 28: Min = 19.0, Avg = 22.23
# Geração 29: Min = 19.0, Avg = 22.3
# Geração 30: Min = 19.0, Avg = 22.2
# Geração 31: Min = 18.0, Avg = 21.98
# Geração 32: Min = 18.0, Avg = 22.38
# Geração 33: Min = 18.0, Avg = 21.02
# Geração 34: Min = 18.0, Avg = 20.94
# Geração 35: Min = 18.0, Avg = 20.68
# Geração 36: Min = 18.0, Avg = 21.12
# Geração 37: Min = 18.0, Avg = 19.73
# Geração 38: Min = 18.0, Avg = 20.45
# Geração 39: Min = 18.0, Avg = 20.87
# Geração 40: Min = 18.0, Avg = 20.19
# Geração 41: Min = 18.0, Avg = 20.29
# Geração 42: Min = 18.0, Avg = 19.77
# Geração 43: Min = 18.0, Avg = 20.7
# Geração 44: Min = 18.0, Avg = 20.46
# Geração 45: Min = 18.0, Avg = 20.97
# Geração 46: Min = 18.0, Avg = 20.04
# Geração 47: Min = 18.0, Avg = 21.09
# Geração 48: Min = 18.0, Avg = 21.88
# Geração 49: Min = 18.0, Avg = 19.48
# Geração 50: Min = 18.0, Avg = 20.2
# Geração 51: Min = 18.0, Avg = 20.58
# Geração 52: Min = 18.0, Avg = 19.82
# Geração 53: Min = 18.0, Avg = 20.01
# Geração 54: Min = 18.0, Avg = 19.66
# Geração 55: Min = 18.0, Avg = 21.29
# Geração 56: Min = 18.0, Avg = 20.05
# Geração 57: Min = 18.0, Avg = 20.11
# Geração 58: Min = 18.0, Avg = 20.4
# Geração 59: Min = 18.0, Avg = 20.5
# Geração 60: Min = 18.0, Avg = 19.54
# Geração 61: Min = 18.0, Avg = 20.09
# Geração 62: Min = 18.0, Avg = 19.08
# Geração 63: Min = 18.0, Avg = 20.66
# Geração 64: Min = 18.0, Avg = 20.88
# Geração 65: Min = 18.0, Avg = 20.24
# Geração 66: Min = 18.0, Avg = 19.6
# Geração 67: Min = 18.0, Avg = 20.68
# Geração 68: Min = 18.0, Avg = 19.53
# Geração 69: Min = 18.0, Avg = 20.31
# Geração 70: Min = 18.0, Avg = 21.24
# Geração 71: Min = 18.0, Avg = 20.69
# Geração 72: Min = 18.0, Avg = 19.89
# Geração 73: Min = 18.0, Avg = 19.42
# Geração 74: Min = 18.0, Avg = 20.99
# Geração 75: Min = 18.0, Avg = 19.56
# Geração 76: Min = 18.0, Avg = 20.27
# Geração 77: Min = 18.0, Avg = 19.4
# Geração 78: Min = 18.0, Avg = 19.98
# Geração 79: Min = 18.0, Avg = 19.29
# Geração 80: Min = 18.0, Avg = 19.43
# Geração 81: Min = 18.0, Avg = 20.84
# Geração 82: Min = 18.0, Avg = 19.35
# Geração 83: Min = 18.0, Avg = 20.81
# Geração 84: Min = 18.0, Avg = 19.93
# Geração 85: Min = 18.0, Avg = 19.6
# Geração 86: Min = 18.0, Avg = 19.7
# Geração 87: Min = 18.0, Avg = 20.49
# Geração 88: Min = 18.0, Avg = 20.5
# Geração 89: Min = 18.0, Avg = 19.38
# Geração 90: Min = 18.0, Avg = 20.06
# Geração 91: Min = 18.0, Avg = 19.92
# Geração 92: Min = 18.0, Avg = 20.31
# Geração 93: Min = 18.0, Avg = 20.57
# Geração 94: Min = 18.0, Avg = 19.72
# Geração 95: Min = 18.0, Avg = 20.42
# Geração 96: Min = 18.0, Avg = 20.54
# Geração 97: Min = 18.0, Avg = 19.85
# Geração 98: Min = 18.0, Avg = 19.28
# Geração 99: Min = 18.0, Avg = 19.6
# Geração 0: Min = 29.0, Avg = 45.58
# Geração 1: Min = 29.0, Avg = 40.18
# Geração 2: Min = 29.0, Avg = 38.49
# Geração 3: Min = 28.0, Avg = 36.64
# Geração 4: Min = 28.0, Avg = 35.07
# Geração 5: Min = 27.0, Avg = 34.78
# Geração 6: Min = 26.0, Avg = 34.39
# Geração 7: Min = 26.0, Avg = 31.77
# Geração 8: Min = 25.0, Avg = 31.07
# Geração 9: Min = 25.0, Avg = 29.38
# Geração 10: Min = 24.0, Avg = 28.54
# Geração 11: Min = 23.0, Avg = 27.08
# Geração 12: Min = 23.0, Avg = 26.81
# Geração 13: Min = 22.0, Avg = 26.57
# Geração 14: Min = 21.0, Avg = 26.61
# Geração 15: Min = 21.0, Avg = 26.27
# Geração 16: Min = 21.0, Avg = 25.49
# Geração 17: Min = 20.0, Avg = 25.44
# Geração 18: Min = 20.0, Avg = 25.14
# Geração 19: Min = 20.0, Avg = 24.78
# Geração 20: Min = 20.0, Avg = 23.46
# Geração 21: Min = 20.0, Avg = 24.66
# Geração 22: Min = 20.0, Avg = 23.95
# Geração 23: Min = 20.0, Avg = 24.92
# Geração 24: Min = 20.0, Avg = 24.79
# Geração 25: Min = 18.0, Avg = 23.31
# Geração 26: Min = 18.0, Avg = 25.5
# Geração 27: Min = 18.0, Avg = 23.48
# Geração 28: Min = 18.0, Avg = 22.54
# Geração 29: Min = 18.0, Avg = 22.84
# Geração 30: Min = 18.0, Avg = 21.39
# Geração 31: Min = 18.0, Avg = 20.29
# Geração 32: Min = 18.0, Avg = 20.89
# Geração 33: Min = 18.0, Avg = 19.28
# Geração 34: Min = 18.0, Avg = 19.68
# Geração 35: Min = 18.0, Avg = 20.38
# Geração 36: Min = 18.0, Avg = 20.08
# Geração 37: Min = 18.0, Avg = 20.51
# Geração 38: Min = 18.0, Avg = 20.01
# Geração 39: Min = 18.0, Avg = 20.57
# Geração 40: Min = 18.0, Avg = 20.07
# Geração 41: Min = 18.0, Avg = 19.52
# Geração 42: Min = 18.0, Avg = 20.3
# Geração 43: Min = 18.0, Avg = 19.88
# Geração 44: Min = 18.0, Avg = 20.85
# Geração 45: Min = 18.0, Avg = 19.57
# Geração 46: Min = 18.0, Avg = 20.11
# Geração 47: Min = 18.0, Avg = 20.88
# Geração 48: Min = 18.0, Avg = 20.36
# Geração 49: Min = 18.0, Avg = 19.76
# Geração 50: Min = 18.0, Avg = 20.67
# Geração 51: Min = 18.0, Avg = 18.96
# Geração 52: Min = 18.0, Avg = 19.86
# Geração 53: Min = 18.0, Avg = 20.16
# Geração 54: Min = 18.0, Avg = 20.33
# Geração 55: Min = 18.0, Avg = 19.52
# Geração 56: Min = 18.0, Avg = 21.2
# Geração 57: Min = 18.0, Avg = 20.39
# Geração 58: Min = 18.0, Avg = 20.77
# Geração 59: Min = 18.0, Avg = 20.56
# Geração 60: Min = 18.0, Avg = 20.88
# Geração 61: Min = 18.0, Avg = 20.36
# Geração 62: Min = 18.0, Avg = 20.35
# Geração 63: Min = 18.0, Avg = 19.7
# Geração 64: Min = 18.0, Avg = 20.25
# Geração 65: Min = 18.0, Avg = 19.98
# Geração 66: Min = 18.0, Avg = 20.84
# Geração 67: Min = 18.0, Avg = 20.73
# Geração 68: Min = 18.0, Avg = 19.87
# Geração 69: Min = 18.0, Avg = 19.76
# Geração 70: Min = 18.0, Avg = 19.53
# Geração 71: Min = 18.0, Avg = 19.98
# Geração 72: Min = 18.0, Avg = 20.03
# Geração 73: Min = 18.0, Avg = 19.67
# Geração 74: Min = 18.0, Avg = 20.39
# Geração 75: Min = 18.0, Avg = 19.55
# Geração 76: Min = 18.0, Avg = 20.35
# Geração 77: Min = 18.0, Avg = 20.85
# Geração 78: Min = 18.0, Avg = 19.5
# Geração 79: Min = 18.0, Avg = 19.05
# Geração 80: Min = 18.0, Avg = 20.09
# Geração 81: Min = 18.0, Avg = 19.6
# Geração 82: Min = 18.0, Avg = 19.52
# Geração 83: Min = 18.0, Avg = 20.15
# Geração 84: Min = 18.0, Avg = 19.84
# Geração 85: Min = 18.0, Avg = 21.15
# Geração 86: Min = 18.0, Avg = 19.42
# Geração 87: Min = 18.0, Avg = 20.76
# Geração 88: Min = 18.0, Avg = 19.79
# Geração 89: Min = 18.0, Avg = 20.7
# Geração 90: Min = 18.0, Avg = 20.24
# Geração 91: Min = 18.0, Avg = 19.57
# Geração 92: Min = 18.0, Avg = 19.98
# Geração 93: Min = 18.0, Avg = 20.22
# Geração 94: Min = 18.0, Avg = 20.8
# Geração 95: Min = 18.0, Avg = 20.37
# Geração 96: Min = 18.0, Avg = 19.96
# Geração 97: Min = 18.0, Avg = 20.42
# Geração 98: Min = 18.0, Avg = 20.66
# Geração 99: Min = 18.0, Avg = 21.56
# Geração 0: Min = 30.0, Avg = 43.97
# Geração 1: Min = 29.0, Avg = 39.93
# Geração 2: Min = 29.0, Avg = 37.81
# Geração 3: Min = 27.0, Avg = 36.86
# Geração 4: Min = 26.0, Avg = 35.03
# Geração 5: Min = 26.0, Avg = 35.01
# Geração 6: Min = 25.0, Avg = 34.61
# Geração 7: Min = 25.0, Avg = 33.78
# Geração 8: Min = 24.0, Avg = 32.76
# Geração 9: Min = 23.0, Avg = 29.43
# Geração 10: Min = 23.0, Avg = 29.37
# Geração 11: Min = 23.0, Avg = 27.41
# Geração 12: Min = 21.0, Avg = 26.06
# Geração 13: Min = 21.0, Avg = 24.96
# Geração 14: Min = 20.0, Avg = 25.6
# Geração 15: Min = 20.0, Avg = 24.53
# Geração 16: Min = 20.0, Avg = 25.14
# Geração 17: Min = 19.0, Avg = 23.36
# Geração 18: Min = 19.0, Avg = 23.03
# Geração 19: Min = 18.0, Avg = 22.9
# Geração 20: Min = 19.0, Avg = 22.24
# Geração 21: Min = 18.0, Avg = 22.27
# Geração 22: Min = 18.0, Avg = 21.36
# Geração 23: Min = 18.0, Avg = 21.22
# Geração 24: Min = 18.0, Avg = 20.44
# Geração 25: Min = 18.0, Avg = 20.69
# Geração 26: Min = 18.0, Avg = 19.7
# Geração 27: Min = 18.0, Avg = 19.73
# Geração 28: Min = 18.0, Avg = 20.69
# Geração 29: Min = 18.0, Avg = 20.59
# Geração 30: Min = 18.0, Avg = 20.77
# Geração 31: Min = 18.0, Avg = 20.03
# Geração 32: Min = 18.0, Avg = 20.71
# Geração 33: Min = 18.0, Avg = 20.08
# Geração 34: Min = 17.0, Avg = 20.09
# Geração 35: Min = 18.0, Avg = 20.35
# Geração 36: Min = 18.0, Avg = 20.52
# Geração 37: Min = 18.0, Avg = 20.17
# Geração 38: Min = 18.0, Avg = 19.95
# Geração 39: Min = 18.0, Avg = 20.21
# Geração 40: Min = 18.0, Avg = 19.41
# Geração 41: Min = 18.0, Avg = 20.13
# Geração 42: Min = 18.0, Avg = 19.53
# Geração 43: Min = 18.0, Avg = 20.91
# Geração 44: Min = 18.0, Avg = 18.96
# Geração 45: Min = 18.0, Avg = 20.31
# Geração 46: Min = 18.0, Avg = 19.64
# Geração 47: Min = 18.0, Avg = 20.12
# Geração 48: Min = 18.0, Avg = 20.24
# Geração 49: Min = 18.0, Avg = 19.93
# Geração 50: Min = 18.0, Avg = 19.59
# Geração 51: Min = 18.0, Avg = 21.05
# Geração 52: Min = 18.0, Avg = 20.17
# Geração 53: Min = 18.0, Avg = 20.93
# Geração 54: Min = 18.0, Avg = 20.65
# Geração 55: Min = 18.0, Avg = 20.09
# Geração 56: Min = 18.0, Avg = 21.06
# Geração 57: Min = 18.0, Avg = 20.88
# Geração 58: Min = 18.0, Avg = 19.83
# Geração 59: Min = 18.0, Avg = 20.01
# Geração 60: Min = 18.0, Avg = 20.02
# Geração 61: Min = 17.0, Avg = 20.31
# Geração 62: Min = 17.0, Avg = 20.74
# Geração 63: Min = 17.0, Avg = 20.73
# Geração 64: Min = 17.0, Avg = 20.51
# Geração 65: Min = 17.0, Avg = 19.82
# Geração 66: Min = 17.0, Avg = 20.19
# Geração 67: Min = 17.0, Avg = 19.96
# Geração 68: Min = 17.0, Avg = 18.25
# Geração 69: Min = 17.0, Avg = 19.16
# Geração 70: Min = 17.0, Avg = 19.51
# Geração 71: Min = 17.0, Avg = 18.39
# Geração 72: Min = 17.0, Avg = 21.71
# Geração 73: Min = 17.0, Avg = 19.49
# Geração 74: Min = 17.0, Avg = 20.06
# Geração 75: Min = 17.0, Avg = 18.95
# Geração 76: Min = 17.0, Avg = 18.67
# Geração 77: Min = 17.0, Avg = 19.21
# Geração 78: Min = 17.0, Avg = 18.63
# Geração 79: Min = 17.0, Avg = 18.88
# Geração 80: Min = 17.0, Avg = 19.12
# Geração 81: Min = 17.0, Avg = 19.48
# Geração 82: Min = 17.0, Avg = 18.76
# Geração 83: Min = 17.0, Avg = 19.69
# Geração 84: Min = 17.0, Avg = 20.45
# Geração 85: Min = 17.0, Avg = 19.77
# Geração 86: Min = 17.0, Avg = 19.85
# Geração 87: Min = 17.0, Avg = 19.28
# Geração 88: Min = 17.0, Avg = 19.71
# Geração 89: Min = 17.0, Avg = 19.43
# Geração 90: Min = 17.0, Avg = 18.22
# Geração 91: Min = 17.0, Avg = 19.89
# Geração 92: Min = 17.0, Avg = 19.87
# Geração 93: Min = 17.0, Avg = 19.47
# Geração 94: Min = 17.0, Avg = 19.23
# Geração 95: Min = 17.0, Avg = 19.29
# Geração 96: Min = 17.0, Avg = 19.84
# Geração 97: Min = 17.0, Avg = 19.13
# Geração 98: Min = 17.0, Avg = 19.16
# Geração 99: Min = 17.0, Avg = 20.06
# Geração 0: Min = 27.0, Avg = 45.94
# Geração 1: Min = 29.0, Avg = 40.66
# Geração 2: Min = 28.0, Avg = 37.41
# Geração 3: Min = 27.0, Avg = 35.75
# Geração 4: Min = 27.0, Avg = 35.79
# Geração 5: Min = 26.0, Avg = 35.16
# Geração 6: Min = 25.0, Avg = 35.47
# Geração 7: Min = 25.0, Avg = 34.18
# Geração 8: Min = 25.0, Avg = 34.13
# Geração 9: Min = 24.0, Avg = 33.1
# Geração 10: Min = 24.0, Avg = 33.0
# Geração 11: Min = 23.0, Avg = 34.52
# Geração 12: Min = 23.0, Avg = 31.72
# Geração 13: Min = 23.0, Avg = 34.2
# Geração 14: Min = 23.0, Avg = 32.78
# Geração 15: Min = 23.0, Avg = 31.2
# Geração 16: Min = 22.0, Avg = 31.7
# Geração 17: Min = 22.0, Avg = 32.05
# Geração 18: Min = 22.0, Avg = 32.91
# Geração 19: Min = 22.0, Avg = 31.01
# Geração 20: Min = 21.0, Avg = 29.17
# Geração 21: Min = 21.0, Avg = 27.42
# Geração 22: Min = 21.0, Avg = 25.68
# Geração 23: Min = 20.0, Avg = 25.6
# Geração 24: Min = 20.0, Avg = 25.15
# Geração 25: Min = 20.0, Avg = 25.06
# Geração 26: Min = 20.0, Avg = 24.14
# Geração 27: Min = 19.0, Avg = 23.98
# Geração 28: Min = 19.0, Avg = 22.93
# Geração 29: Min = 19.0, Avg = 21.81
# Geração 30: Min = 19.0, Avg = 22.9
# Geração 31: Min = 19.0, Avg = 22.0
# Geração 32: Min = 18.0, Avg = 22.77
# Geração 33: Min = 19.0, Avg = 21.49
# Geração 34: Min = 19.0, Avg = 21.67
# Geração 35: Min = 18.0, Avg = 22.61
# Geração 36: Min = 18.0, Avg = 22.04
# Geração 37: Min = 18.0, Avg = 23.23
# Geração 38: Min = 18.0, Avg = 20.6
# Geração 39: Min = 18.0, Avg = 21.74
# Geração 40: Min = 18.0, Avg = 22.08
# Geração 41: Min = 18.0, Avg = 19.82
# Geração 42: Min = 18.0, Avg = 20.46
# Geração 43: Min = 18.0, Avg = 21.13
# Geração 44: Min = 18.0, Avg = 19.52
# Geração 45: Min = 18.0, Avg = 20.77
# Geração 46: Min = 18.0, Avg = 20.61
# Geração 47: Min = 18.0, Avg = 19.91
# Geração 48: Min = 18.0, Avg = 20.28
# Geração 49: Min = 18.0, Avg = 21.75
# Geração 50: Min = 18.0, Avg = 20.89
# Geração 51: Min = 18.0, Avg = 20.42
# Geração 52: Min = 18.0, Avg = 20.67
# Geração 53: Min = 18.0, Avg = 19.85
# Geração 54: Min = 18.0, Avg = 20.33
# Geração 55: Min = 18.0, Avg = 20.06
# Geração 56: Min = 18.0, Avg = 21.36
# Geração 57: Min = 18.0, Avg = 21.01
# Geração 58: Min = 18.0, Avg = 20.49
# Geração 59: Min = 18.0, Avg = 19.7
# Geração 60: Min = 18.0, Avg = 20.78
# Geração 61: Min = 18.0, Avg = 19.53
# Geração 62: Min = 18.0, Avg = 20.13
# Geração 63: Min = 18.0, Avg = 20.54
# Geração 64: Min = 18.0, Avg = 20.6
# Geração 65: Min = 18.0, Avg = 19.67
# Geração 66: Min = 18.0, Avg = 20.48
# Geração 67: Min = 18.0, Avg = 19.23
# Geração 68: Min = 18.0, Avg = 20.95
# Geração 69: Min = 18.0, Avg = 21.1
# Geração 70: Min = 18.0, Avg = 20.01
# Geração 71: Min = 18.0, Avg = 20.79
# Geração 72: Min = 18.0, Avg = 19.21
# Geração 73: Min = 18.0, Avg = 20.97
# Geração 74: Min = 18.0, Avg = 19.68
# Geração 75: Min = 18.0, Avg = 19.92
# Geração 76: Min = 18.0, Avg = 20.35
# Geração 77: Min = 18.0, Avg = 20.66
# Geração 78: Min = 18.0, Avg = 20.11
# Geração 79: Min = 18.0, Avg = 20.3
# Geração 80: Min = 18.0, Avg = 20.27
# Geração 81: Min = 17.0, Avg = 20.17
# Geração 82: Min = 17.0, Avg = 20.76
# Geração 83: Min = 17.0, Avg = 20.49
# Geração 84: Min = 17.0, Avg = 20.46
# Geração 85: Min = 17.0, Avg = 20.92
# Geração 86: Min = 17.0, Avg = 21.34
# Geração 87: Min = 17.0, Avg = 20.3
# Geração 88: Min = 17.0, Avg = 20.48
# Geração 89: Min = 17.0, Avg = 20.42
# Geração 90: Min = 17.0, Avg = 19.06
# Geração 91: Min = 17.0, Avg = 19.8
# Geração 92: Min = 17.0, Avg = 19.7
# Geração 93: Min = 17.0, Avg = 19.13
# Geração 94: Min = 17.0, Avg = 20.43
# Geração 95: Min = 17.0, Avg = 19.05
# Geração 96: Min = 17.0, Avg = 19.9
# Geração 97: Min = 17.0, Avg = 19.48
# Geração 98: Min = 17.0, Avg = 19.41
# Geração 99: Min = 17.0, Avg = 19.72
# Geração 0: Min = 29.0, Avg = 42.59
# Geração 1: Min = 29.0, Avg = 39.32
# Geração 2: Min = 28.0, Avg = 37.16
# Geração 3: Min = 28.0, Avg = 37.86
# Geração 4: Min = 27.0, Avg = 36.4
# Geração 5: Min = 27.0, Avg = 36.69
# Geração 6: Min = 25.0, Avg = 33.26
# Geração 7: Min = 25.0, Avg = 33.17
# Geração 8: Min = 24.0, Avg = 32.65
# Geração 9: Min = 26.0, Avg = 31.76
# Geração 10: Min = 25.0, Avg = 31.21
# Geração 11: Min = 24.0, Avg = 30.96
# Geração 12: Min = 24.0, Avg = 29.54
# Geração 13: Min = 23.0, Avg = 28.39
# Geração 14: Min = 22.0, Avg = 28.76
# Geração 15: Min = 22.0, Avg = 27.63
# Geração 16: Min = 21.0, Avg = 28.22
# Geração 17: Min = 21.0, Avg = 26.59
# Geração 18: Min = 20.0, Avg = 27.02
# Geração 19: Min = 20.0, Avg = 25.77
# Geração 20: Min = 20.0, Avg = 24.38
# Geração 21: Min = 20.0, Avg = 24.65
# Geração 22: Min = 20.0, Avg = 23.73
# Geração 23: Min = 19.0, Avg = 22.53
# Geração 24: Min = 19.0, Avg = 22.34
# Geração 25: Min = 19.0, Avg = 23.57
# Geração 26: Min = 19.0, Avg = 21.91
# Geração 27: Min = 19.0, Avg = 22.3
# Geração 28: Min = 19.0, Avg = 21.48
# Geração 29: Min = 19.0, Avg = 21.14
# Geração 30: Min = 19.0, Avg = 21.62
# Geração 31: Min = 19.0, Avg = 21.02
# Geração 32: Min = 18.0, Avg = 21.81
# Geração 33: Min = 18.0, Avg = 20.55
# Geração 34: Min = 18.0, Avg = 21.92
# Geração 35: Min = 18.0, Avg = 22.14
# Geração 36: Min = 18.0, Avg = 21.25
# Geração 37: Min = 18.0, Avg = 20.7
# Geração 38: Min = 18.0, Avg = 20.24
# Geração 39: Min = 18.0, Avg = 19.56
# Geração 40: Min = 18.0, Avg = 19.77
# Geração 41: Min = 18.0, Avg = 20.35
# Geração 42: Min = 18.0, Avg = 19.6
# Geração 43: Min = 18.0, Avg = 20.62
# Geração 44: Min = 18.0, Avg = 20.05
# Geração 45: Min = 18.0, Avg = 20.44
# Geração 46: Min = 18.0, Avg = 20.29
# Geração 47: Min = 18.0, Avg = 19.42
# Geração 48: Min = 18.0, Avg = 20.12
# Geração 49: Min = 18.0, Avg = 20.6
# Geração 50: Min = 18.0, Avg = 19.67
# Geração 51: Min = 18.0, Avg = 20.76
# Geração 52: Min = 18.0, Avg = 20.26
# Geração 53: Min = 18.0, Avg = 19.67
# Geração 54: Min = 18.0, Avg = 19.93
# Geração 55: Min = 18.0, Avg = 19.44
# Geração 56: Min = 18.0, Avg = 19.93
# Geração 57: Min = 18.0, Avg = 19.91
# Geração 58: Min = 18.0, Avg = 21.03
# Geração 59: Min = 18.0, Avg = 20.35
# Geração 60: Min = 18.0, Avg = 20.75
# Geração 61: Min = 18.0, Avg = 19.15
# Geração 62: Min = 18.0, Avg = 19.67
# Geração 63: Min = 18.0, Avg = 19.65
# Geração 64: Min = 18.0, Avg = 19.74
# Geração 65: Min = 18.0, Avg = 19.35
# Geração 66: Min = 18.0, Avg = 20.47
# Geração 67: Min = 18.0, Avg = 20.08
# Geração 68: Min = 18.0, Avg = 19.66
# Geração 69: Min = 18.0, Avg = 20.31
# Geração 70: Min = 18.0, Avg = 19.77
# Geração 71: Min = 18.0, Avg = 19.42
# Geração 72: Min = 18.0, Avg = 19.64
# Geração 73: Min = 18.0, Avg = 20.44
# Geração 74: Min = 18.0, Avg = 20.16
# Geração 75: Min = 18.0, Avg = 20.42
# Geração 76: Min = 18.0, Avg = 19.76
# Geração 77: Min = 18.0, Avg = 20.33
# Geração 78: Min = 18.0, Avg = 20.43
# Geração 79: Min = 18.0, Avg = 19.74
# Geração 80: Min = 18.0, Avg = 20.85
# Geração 81: Min = 18.0, Avg = 19.78
# Geração 82: Min = 18.0, Avg = 20.58
# Geração 83: Min = 18.0, Avg = 19.82
# Geração 84: Min = 18.0, Avg = 19.82
# Geração 85: Min = 18.0, Avg = 20.19
# Geração 86: Min = 18.0, Avg = 20.31
# Geração 87: Min = 18.0, Avg = 20.51
# Geração 88: Min = 18.0, Avg = 19.86
# Geração 89: Min = 18.0, Avg = 19.78
# Geração 90: Min = 18.0, Avg = 20.05
# Geração 91: Min = 18.0, Avg = 19.45
# Geração 92: Min = 18.0, Avg = 19.4
# Geração 93: Min = 18.0, Avg = 20.16
# Geração 94: Min = 18.0, Avg = 20.21
# Geração 95: Min = 18.0, Avg = 19.82
# Geração 96: Min = 18.0, Avg = 20.77
# Geração 97: Min = 18.0, Avg = 20.68
# Geração 98: Min = 18.0, Avg = 19.14
# Geração 99: Min = 18.0, Avg = 19.72
# Geração 0: Min = 29.0, Avg = 47.76
# Geração 1: Min = 29.0, Avg = 41.99
# Geração 2: Min = 29.0, Avg = 39.58
# Geração 3: Min = 28.0, Avg = 36.69
# Geração 4: Min = 27.0, Avg = 37.12
# Geração 5: Min = 26.0, Avg = 36.42
# Geração 6: Min = 26.0, Avg = 35.05
# Geração 7: Min = 27.0, Avg = 35.02
# Geração 8: Min = 26.0, Avg = 33.73
# Geração 9: Min = 26.0, Avg = 33.18
# Geração 10: Min = 25.0, Avg = 35.0
# Geração 11: Min = 24.0, Avg = 31.68
# Geração 12: Min = 23.0, Avg = 33.9
# Geração 13: Min = 23.0, Avg = 34.58
# Geração 14: Min = 22.0, Avg = 33.07
# Geração 15: Min = 21.0, Avg = 31.9
# Geração 16: Min = 21.0, Avg = 30.57
# Geração 17: Min = 23.0, Avg = 29.57
# Geração 18: Min = 23.0, Avg = 29.19
# Geração 19: Min = 22.0, Avg = 29.5
# Geração 20: Min = 22.0, Avg = 26.97
# Geração 21: Min = 21.0, Avg = 27.83
# Geração 22: Min = 21.0, Avg = 25.92
# Geração 23: Min = 21.0, Avg = 25.48
# Geração 24: Min = 20.0, Avg = 24.43
# Geração 25: Min = 20.0, Avg = 23.24
# Geração 26: Min = 20.0, Avg = 23.73
# Geração 27: Min = 20.0, Avg = 22.61
# Geração 28: Min = 20.0, Avg = 21.86
# Geração 29: Min = 20.0, Avg = 21.96
# Geração 30: Min = 20.0, Avg = 21.27
# Geração 31: Min = 20.0, Avg = 23.27
# Geração 32: Min = 20.0, Avg = 21.59
# Geração 33: Min = 20.0, Avg = 21.68
# Geração 34: Min = 20.0, Avg = 22.48
# Geração 35: Min = 20.0, Avg = 21.92
# Geração 36: Min = 20.0, Avg = 21.81
# Geração 37: Min = 20.0, Avg = 22.2
# Geração 38: Min = 20.0, Avg = 21.66
# Geração 39: Min = 20.0, Avg = 22.49
# Geração 40: Min = 20.0, Avg = 22.44
# Geração 41: Min = 20.0, Avg = 21.58
# Geração 42: Min = 20.0, Avg = 21.95
# Geração 43: Min = 20.0, Avg = 22.51
# Geração 44: Min = 20.0, Avg = 21.84
# Geração 45: Min = 20.0, Avg = 22.38
# Geração 46: Min = 20.0, Avg = 21.41
# Geração 47: Min = 20.0, Avg = 22.2
# Geração 48: Min = 20.0, Avg = 22.12
# Geração 49: Min = 20.0, Avg = 21.12
# Geração 50: Min = 20.0, Avg = 21.74
# Geração 51: Min = 20.0, Avg = 22.78
# Geração 52: Min = 20.0, Avg = 22.0
# Geração 53: Min = 19.0, Avg = 21.63
# Geração 54: Min = 19.0, Avg = 22.51
# Geração 55: Min = 19.0, Avg = 22.34
# Geração 56: Min = 19.0, Avg = 21.79
# Geração 57: Min = 19.0, Avg = 21.67
# Geração 58: Min = 19.0, Avg = 20.88
# Geração 59: Min = 19.0, Avg = 20.51
# Geração 60: Min = 19.0, Avg = 21.09
# Geração 61: Min = 18.0, Avg = 20.99
# Geração 62: Min = 19.0, Avg = 20.79
# Geração 63: Min = 19.0, Avg = 20.63
# Geração 64: Min = 18.0, Avg = 20.84
# Geração 65: Min = 19.0, Avg = 22.61
# Geração 66: Min = 19.0, Avg = 21.49
# Geração 67: Min = 19.0, Avg = 20.96
# Geração 68: Min = 18.0, Avg = 21.73
# Geração 69: Min = 18.0, Avg = 21.38
# Geração 70: Min = 18.0, Avg = 22.93
# Geração 71: Min = 18.0, Avg = 20.94
# Geração 72: Min = 18.0, Avg = 21.02
# Geração 73: Min = 18.0, Avg = 21.75
# Geração 74: Min = 18.0, Avg = 22.23
# Geração 75: Min = 18.0, Avg = 20.24
# Geração 76: Min = 18.0, Avg = 21.95
# Geração 77: Min = 18.0, Avg = 19.74
# Geração 78: Min = 18.0, Avg = 20.22
# Geração 79: Min = 18.0, Avg = 20.37
# Geração 80: Min = 18.0, Avg = 19.84
# Geração 81: Min = 18.0, Avg = 19.48
# Geração 82: Min = 18.0, Avg = 20.48
# Geração 83: Min = 18.0, Avg = 19.76
# Geração 84: Min = 18.0, Avg = 20.2
# Geração 85: Min = 18.0, Avg = 20.48
# Geração 86: Min = 18.0, Avg = 20.45
# Geração 87: Min = 18.0, Avg = 19.68
# Geração 88: Min = 18.0, Avg = 19.87
# Geração 89: Min = 18.0, Avg = 19.8
# Geração 90: Min = 18.0, Avg = 19.47
# Geração 91: Min = 18.0, Avg = 20.03
# Geração 92: Min = 18.0, Avg = 21.82
# Geração 93: Min = 18.0, Avg = 20.73
# Geração 94: Min = 18.0, Avg = 20.28
# Geração 95: Min = 18.0, Avg = 20.31
# Geração 96: Min = 18.0, Avg = 20.24
# Geração 97: Min = 18.0, Avg = 19.95
# Geração 98: Min = 18.0, Avg = 19.98
# Geração 99: Min = 18.0, Avg = 19.47
# Geração 0: Min = 26.0, Avg = 45.33
# Geração 1: Min = 26.0, Avg = 40.03
# Geração 2: Min = 26.0, Avg = 37.97
# Geração 3: Min = 25.0, Avg = 36.34
# Geração 4: Min = 26.0, Avg = 36.32
# Geração 5: Min = 25.0, Avg = 35.53
# Geração 6: Min = 24.0, Avg = 35.16
# Geração 7: Min = 23.0, Avg = 34.46
# Geração 8: Min = 23.0, Avg = 33.85
# Geração 9: Min = 25.0, Avg = 33.82
# Geração 10: Min = 24.0, Avg = 32.86
# Geração 11: Min = 23.0, Avg = 32.93
# Geração 12: Min = 23.0, Avg = 31.74
# Geração 13: Min = 23.0, Avg = 31.15
# Geração 14: Min = 22.0, Avg = 29.25
# Geração 15: Min = 21.0, Avg = 27.04
# Geração 16: Min = 20.0, Avg = 25.36
# Geração 17: Min = 20.0, Avg = 24.38
# Geração 18: Min = 19.0, Avg = 24.42
# Geração 19: Min = 19.0, Avg = 22.85
# Geração 20: Min = 18.0, Avg = 22.66
# Geração 21: Min = 18.0, Avg = 21.86
# Geração 22: Min = 17.0, Avg = 22.2
# Geração 23: Min = 17.0, Avg = 23.01
# Geração 24: Min = 18.0, Avg = 22.34
# Geração 25: Min = 17.0, Avg = 24.15
# Geração 26: Min = 17.0, Avg = 23.43
# Geração 27: Min = 17.0, Avg = 22.41
# Geração 28: Min = 17.0, Avg = 23.73
# Geração 29: Min = 17.0, Avg = 21.88
# Geração 30: Min = 17.0, Avg = 21.59
# Geração 31: Min = 17.0, Avg = 20.75
# Geração 32: Min = 17.0, Avg = 19.86
# Geração 33: Min = 17.0, Avg = 19.64
# Geração 34: Min = 17.0, Avg = 20.17
# Geração 35: Min = 17.0, Avg = 19.09
# Geração 36: Min = 17.0, Avg = 18.53
# Geração 37: Min = 17.0, Avg = 19.49
# Geração 38: Min = 17.0, Avg = 18.45
# Geração 39: Min = 17.0, Avg = 19.98
# Geração 40: Min = 17.0, Avg = 19.45
# Geração 41: Min = 17.0, Avg = 19.23
# Geração 42: Min = 17.0, Avg = 19.5
# Geração 43: Min = 17.0, Avg = 19.96
# Geração 44: Min = 17.0, Avg = 19.71
# Geração 45: Min = 17.0, Avg = 18.95
# Geração 46: Min = 17.0, Avg = 19.53
# Geração 47: Min = 17.0, Avg = 19.07
# Geração 48: Min = 17.0, Avg = 20.29
# Geração 49: Min = 17.0, Avg = 18.71
# Geração 50: Min = 17.0, Avg = 20.07
# Geração 51: Min = 17.0, Avg = 18.35
# Geração 52: Min = 17.0, Avg = 18.78
# Geração 53: Min = 17.0, Avg = 18.9
# Geração 54: Min = 17.0, Avg = 19.49
# Geração 55: Min = 17.0, Avg = 20.29
# Geração 56: Min = 17.0, Avg = 19.58
# Geração 57: Min = 17.0, Avg = 19.39
# Geração 58: Min = 17.0, Avg = 19.44
# Geração 59: Min = 17.0, Avg = 19.98
# Geração 60: Min = 17.0, Avg = 20.4
# Geração 61: Min = 17.0, Avg = 20.32
# Geração 62: Min = 17.0, Avg = 20.15
# Geração 63: Min = 17.0, Avg = 19.61
# Geração 64: Min = 17.0, Avg = 19.88
# Geração 65: Min = 17.0, Avg = 19.66
# Geração 66: Min = 17.0, Avg = 18.46
# Geração 67: Min = 17.0, Avg = 19.58
# Geração 68: Min = 17.0, Avg = 19.56
# Geração 69: Min = 17.0, Avg = 18.64
# Geração 70: Min = 17.0, Avg = 19.02
# Geração 71: Min = 17.0, Avg = 19.2
# Geração 72: Min = 17.0, Avg = 19.78
# Geração 73: Min = 17.0, Avg = 19.4
# Geração 74: Min = 17.0, Avg = 19.67
# Geração 75: Min = 17.0, Avg = 19.45
# Geração 76: Min = 17.0, Avg = 18.89
# Geração 77: Min = 17.0, Avg = 20.08
# Geração 78: Min = 17.0, Avg = 19.13
# Geração 79: Min = 17.0, Avg = 18.67
# Geração 80: Min = 17.0, Avg = 18.64
# Geração 81: Min = 17.0, Avg = 19.42
# Geração 82: Min = 17.0, Avg = 19.53
# Geração 83: Min = 17.0, Avg = 19.49
# Geração 84: Min = 17.0, Avg = 19.82
# Geração 85: Min = 17.0, Avg = 18.57
# Geração 86: Min = 17.0, Avg = 19.76
# Geração 87: Min = 17.0, Avg = 19.06
# Geração 88: Min = 17.0, Avg = 19.78
# Geração 89: Min = 17.0, Avg = 19.56
# Geração 90: Min = 17.0, Avg = 19.2
# Geração 91: Min = 17.0, Avg = 19.0
# Geração 92: Min = 17.0, Avg = 20.29
# Geração 93: Min = 17.0, Avg = 19.89
# Geração 94: Min = 17.0, Avg = 19.92
# Geração 95: Min = 17.0, Avg = 20.39
# Geração 96: Min = 17.0, Avg = 19.09
# Geração 97: Min = 17.0, Avg = 18.84
# Geração 98: Min = 17.0, Avg = 19.67
# Geração 99: Min = 17.0, Avg = 19.45
# Geração 0: Min = 30.0, Avg = 43.53
# Geração 1: Min = 29.0, Avg = 38.77
# Geração 2: Min = 28.0, Avg = 37.46
# Geração 3: Min = 27.0, Avg = 38.12
# Geração 4: Min = 27.0, Avg = 36.83
# Geração 5: Min = 26.0, Avg = 35.76
# Geração 6: Min = 26.0, Avg = 35.37
# Geração 7: Min = 24.0, Avg = 34.16
# Geração 8: Min = 24.0, Avg = 32.75
# Geração 9: Min = 24.0, Avg = 30.88
# Geração 10: Min = 23.0, Avg = 29.23
# Geração 11: Min = 22.0, Avg = 28.86
# Geração 12: Min = 21.0, Avg = 27.75
# Geração 13: Min = 21.0, Avg = 28.28
# Geração 14: Min = 21.0, Avg = 27.46
# Geração 15: Min = 20.0, Avg = 28.44
# Geração 16: Min = 19.0, Avg = 25.94
# Geração 17: Min = 19.0, Avg = 25.23
# Geração 18: Min = 19.0, Avg = 25.7
# Geração 19: Min = 19.0, Avg = 24.73
# Geração 20: Min = 19.0, Avg = 24.12
# Geração 21: Min = 18.0, Avg = 25.34
# Geração 22: Min = 18.0, Avg = 24.41
# Geração 23: Min = 18.0, Avg = 22.62
# Geração 24: Min = 18.0, Avg = 22.46
# Geração 25: Min = 18.0, Avg = 21.09
# Geração 26: Min = 18.0, Avg = 21.48
# Geração 27: Min = 18.0, Avg = 21.21
# Geração 28: Min = 18.0, Avg = 21.66
# Geração 29: Min = 18.0, Avg = 19.55
# Geração 30: Min = 18.0, Avg = 20.65
# Geração 31: Min = 18.0, Avg = 20.5
# Geração 32: Min = 18.0, Avg = 20.37
# Geração 33: Min = 18.0, Avg = 20.13
# Geração 34: Min = 18.0, Avg = 20.92
# Geração 35: Min = 18.0, Avg = 19.95
# Geração 36: Min = 18.0, Avg = 19.73
# Geração 37: Min = 18.0, Avg = 20.5
# Geração 38: Min = 18.0, Avg = 20.99
# Geração 39: Min = 18.0, Avg = 19.68
# Geração 40: Min = 18.0, Avg = 19.57
# Geração 41: Min = 18.0, Avg = 21.03
# Geração 42: Min = 18.0, Avg = 20.46
# Geração 43: Min = 18.0, Avg = 20.52
# Geração 44: Min = 18.0, Avg = 20.52
# Geração 45: Min = 18.0, Avg = 20.72
# Geração 46: Min = 18.0, Avg = 20.91
# Geração 47: Min = 18.0, Avg = 20.69
# Geração 48: Min = 18.0, Avg = 19.79
# Geração 49: Min = 18.0, Avg = 20.65
# Geração 50: Min = 17.0, Avg = 19.67
# Geração 51: Min = 17.0, Avg = 19.59
# Geração 52: Min = 17.0, Avg = 20.05
# Geração 53: Min = 17.0, Avg = 19.47
# Geração 54: Min = 17.0, Avg = 20.05
# Geração 55: Min = 17.0, Avg = 21.33
# Geração 56: Min = 17.0, Avg = 20.37
# Geração 57: Min = 17.0, Avg = 19.44
# Geração 58: Min = 17.0, Avg = 19.01
# Geração 59: Min = 17.0, Avg = 19.15
# Geração 60: Min = 17.0, Avg = 19.61
# Geração 61: Min = 17.0, Avg = 20.14
# Geração 62: Min = 17.0, Avg = 18.7
# Geração 63: Min = 17.0, Avg = 19.74
# Geração 64: Min = 17.0, Avg = 19.44
# Geração 65: Min = 17.0, Avg = 18.71
# Geração 66: Min = 17.0, Avg = 19.72
# Geração 67: Min = 17.0, Avg = 19.11
# Geração 68: Min = 17.0, Avg = 18.18
# Geração 69: Min = 17.0, Avg = 18.71
# Geração 70: Min = 17.0, Avg = 20.59
# Geração 71: Min = 17.0, Avg = 20.53
# Geração 72: Min = 17.0, Avg = 20.19
# Geração 73: Min = 17.0, Avg = 19.67
# Geração 74: Min = 17.0, Avg = 19.08
# Geração 75: Min = 17.0, Avg = 19.1
# Geração 76: Min = 17.0, Avg = 18.49
# Geração 77: Min = 17.0, Avg = 18.73
# Geração 78: Min = 17.0, Avg = 19.6
# Geração 79: Min = 17.0, Avg = 19.7
# Geração 80: Min = 17.0, Avg = 19.23
# Geração 81: Min = 17.0, Avg = 19.6
# Geração 82: Min = 17.0, Avg = 19.52
# Geração 83: Min = 17.0, Avg = 20.52
# Geração 84: Min = 17.0, Avg = 20.45
# Geração 85: Min = 17.0, Avg = 18.48
# Geração 86: Min = 17.0, Avg = 19.9
# Geração 87: Min = 17.0, Avg = 20.4
# Geração 88: Min = 17.0, Avg = 18.27
# Geração 89: Min = 17.0, Avg = 19.61
# Geração 90: Min = 17.0, Avg = 19.53
# Geração 91: Min = 17.0, Avg = 19.76
# Geração 92: Min = 17.0, Avg = 19.88
# Geração 93: Min = 17.0, Avg = 21.74
# Geração 94: Min = 17.0, Avg = 19.26
# Geração 95: Min = 17.0, Avg = 18.53
# Geração 96: Min = 17.0, Avg = 20.11
# Geração 97: Min = 17.0, Avg = 19.87
# Geração 98: Min = 17.0, Avg = 19.66
# Geração 99: Min = 17.0, Avg = 19.08
# Geração 0: Min = 28.0, Avg = 45.12
# Geração 1: Min = 28.0, Avg = 40.39
# Geração 2: Min = 28.0, Avg = 39.03
# Geração 3: Min = 28.0, Avg = 37.7
# Geração 4: Min = 27.0, Avg = 36.96
# Geração 5: Min = 26.0, Avg = 38.28
# Geração 6: Min = 26.0, Avg = 37.03
# Geração 7: Min = 26.0, Avg = 35.23
# Geração 8: Min = 25.0, Avg = 34.34
# Geração 9: Min = 24.0, Avg = 31.94
# Geração 10: Min = 24.0, Avg = 30.44
# Geração 11: Min = 23.0, Avg = 28.66
# Geração 12: Min = 23.0, Avg = 27.07
# Geração 13: Min = 22.0, Avg = 26.8
# Geração 14: Min = 22.0, Avg = 25.51
# Geração 15: Min = 20.0, Avg = 25.73
# Geração 16: Min = 20.0, Avg = 24.54
# Geração 17: Min = 20.0, Avg = 24.81
# Geração 18: Min = 20.0, Avg = 24.26
# Geração 19: Min = 19.0, Avg = 24.36
# Geração 20: Min = 19.0, Avg = 24.24
# Geração 21: Min = 19.0, Avg = 23.6
# Geração 22: Min = 19.0, Avg = 24.27
# Geração 23: Min = 19.0, Avg = 22.9
# Geração 24: Min = 18.0, Avg = 22.31
# Geração 25: Min = 18.0, Avg = 22.26
# Geração 26: Min = 18.0, Avg = 21.94
# Geração 27: Min = 18.0, Avg = 21.77
# Geração 28: Min = 18.0, Avg = 20.8
# Geração 29: Min = 18.0, Avg = 21.26
# Geração 30: Min = 18.0, Avg = 21.14
# Geração 31: Min = 18.0, Avg = 20.18
# Geração 32: Min = 18.0, Avg = 21.71
# Geração 33: Min = 18.0, Avg = 19.86
# Geração 34: Min = 18.0, Avg = 20.01
# Geração 35: Min = 18.0, Avg = 21.33
# Geração 36: Min = 18.0, Avg = 21.1
# Geração 37: Min = 18.0, Avg = 20.55
# Geração 38: Min = 18.0, Avg = 20.78
# Geração 39: Min = 18.0, Avg = 20.91
# Geração 40: Min = 18.0, Avg = 21.12
# Geração 41: Min = 18.0, Avg = 19.87
# Geração 42: Min = 18.0, Avg = 20.1
# Geração 43: Min = 18.0, Avg = 20.91
# Geração 44: Min = 18.0, Avg = 20.68
# Geração 45: Min = 18.0, Avg = 20.16
# Geração 46: Min = 18.0, Avg = 19.36
# Geração 47: Min = 18.0, Avg = 20.37
# Geração 48: Min = 18.0, Avg = 19.66
# Geração 49: Min = 18.0, Avg = 20.08
# Geração 50: Min = 18.0, Avg = 20.74
# Geração 51: Min = 18.0, Avg = 20.72
# Geração 52: Min = 18.0, Avg = 19.8
# Geração 53: Min = 18.0, Avg = 20.33
# Geração 54: Min = 18.0, Avg = 20.31
# Geração 55: Min = 18.0, Avg = 19.2
# Geração 56: Min = 18.0, Avg = 20.18
# Geração 57: Min = 18.0, Avg = 20.49
# Geração 58: Min = 18.0, Avg = 20.82
# Geração 59: Min = 18.0, Avg = 20.98
# Geração 60: Min = 18.0, Avg = 20.63
# Geração 61: Min = 18.0, Avg = 19.86
# Geração 62: Min = 18.0, Avg = 20.13
# Geração 63: Min = 18.0, Avg = 19.92
# Geração 64: Min = 18.0, Avg = 20.36
# Geração 65: Min = 18.0, Avg = 19.1
# Geração 66: Min = 18.0, Avg = 19.67
# Geração 67: Min = 18.0, Avg = 20.16
# Geração 68: Min = 18.0, Avg = 19.52
# Geração 69: Min = 18.0, Avg = 20.07
# Geração 70: Min = 18.0, Avg = 19.56
# Geração 71: Min = 18.0, Avg = 20.13
# Geração 72: Min = 18.0, Avg = 20.25
# Geração 73: Min = 18.0, Avg = 20.84
# Geração 74: Min = 18.0, Avg = 20.91
# Geração 75: Min = 18.0, Avg = 20.97
# Geração 76: Min = 18.0, Avg = 20.87
# Geração 77: Min = 18.0, Avg = 20.96
# Geração 78: Min = 18.0, Avg = 20.6
# Geração 79: Min = 18.0, Avg = 21.23
# Geração 80: Min = 18.0, Avg = 20.19
# Geração 81: Min = 18.0, Avg = 20.29
# Geração 82: Min = 18.0, Avg = 20.03
# Geração 83: Min = 18.0, Avg = 19.79
# Geração 84: Min = 18.0, Avg = 20.65
# Geração 85: Min = 18.0, Avg = 19.0
# Geração 86: Min = 18.0, Avg = 19.16
# Geração 87: Min = 18.0, Avg = 19.47
# Geração 88: Min = 18.0, Avg = 20.03
# Geração 89: Min = 18.0, Avg = 19.62
# Geração 90: Min = 18.0, Avg = 21.01
# Geração 91: Min = 18.0, Avg = 20.08
# Geração 92: Min = 18.0, Avg = 19.43
# Geração 93: Min = 18.0, Avg = 20.81
# Geração 94: Min = 18.0, Avg = 19.86
# Geração 95: Min = 18.0, Avg = 21.46
# Geração 96: Min = 18.0, Avg = 21.33
# Geração 97: Min = 18.0, Avg = 20.59
# Geração 98: Min = 18.0, Avg = 20.22
# Geração 99: Min = 18.0, Avg = 20.27
# Geração 0: Min = 28.0, Avg = 44.82
# Geração 1: Min = 29.0, Avg = 39.21
# Geração 2: Min = 28.0, Avg = 38.28
# Geração 3: Min = 27.0, Avg = 37.08
# Geração 4: Min = 26.0, Avg = 36.84
# Geração 5: Min = 26.0, Avg = 35.04
# Geração 6: Min = 26.0, Avg = 35.9
# Geração 7: Min = 26.0, Avg = 35.07
# Geração 8: Min = 25.0, Avg = 34.25
# Geração 9: Min = 24.0, Avg = 34.53
# Geração 10: Min = 23.0, Avg = 32.87
# Geração 11: Min = 22.0, Avg = 31.89
# Geração 12: Min = 22.0, Avg = 28.13
# Geração 13: Min = 21.0, Avg = 28.02
# Geração 14: Min = 20.0, Avg = 26.64
# Geração 15: Min = 20.0, Avg = 27.91
# Geração 16: Min = 19.0, Avg = 27.36
# Geração 17: Min = 19.0, Avg = 24.82
# Geração 18: Min = 19.0, Avg = 24.38
# Geração 19: Min = 19.0, Avg = 23.23
# Geração 20: Min = 19.0, Avg = 22.5
# Geração 21: Min = 19.0, Avg = 22.57
# Geração 22: Min = 19.0, Avg = 21.67
# Geração 23: Min = 19.0, Avg = 22.04
# Geração 24: Min = 19.0, Avg = 21.14
# Geração 25: Min = 19.0, Avg = 21.14
# Geração 26: Min = 19.0, Avg = 21.81
# Geração 27: Min = 19.0, Avg = 20.3
# Geração 28: Min = 19.0, Avg = 22.06
# Geração 29: Min = 19.0, Avg = 22.47
# Geração 30: Min = 19.0, Avg = 21.69
# Geração 31: Min = 19.0, Avg = 20.73
# Geração 32: Min = 19.0, Avg = 21.08
# Geração 33: Min = 19.0, Avg = 21.76
# Geração 34: Min = 19.0, Avg = 21.55
# Geração 35: Min = 19.0, Avg = 21.33
# Geração 36: Min = 19.0, Avg = 21.65
# Geração 37: Min = 19.0, Avg = 21.95
# Geração 38: Min = 19.0, Avg = 19.99
# Geração 39: Min = 19.0, Avg = 21.24
# Geração 40: Min = 19.0, Avg = 20.94
# Geração 41: Min = 19.0, Avg = 21.62
# Geração 42: Min = 19.0, Avg = 22.0
# Geração 43: Min = 19.0, Avg = 20.04
# Geração 44: Min = 19.0, Avg = 21.25
# Geração 45: Min = 19.0, Avg = 20.58
# Geração 46: Min = 19.0, Avg = 21.0
# Geração 47: Min = 19.0, Avg = 21.02
# Geração 48: Min = 19.0, Avg = 20.5
# Geração 49: Min = 19.0, Avg = 20.14
# Geração 50: Min = 19.0, Avg = 21.3
# Geração 51: Min = 19.0, Avg = 20.77
# Geração 52: Min = 19.0, Avg = 21.04
# Geração 53: Min = 19.0, Avg = 22.01
# Geração 54: Min = 19.0, Avg = 20.6
# Geração 55: Min = 19.0, Avg = 20.75
# Geração 56: Min = 19.0, Avg = 20.73
# Geração 57: Min = 19.0, Avg = 22.09
# Geração 58: Min = 18.0, Avg = 21.62
# Geração 59: Min = 18.0, Avg = 20.48
# Geração 60: Min = 18.0, Avg = 21.34
# Geração 61: Min = 18.0, Avg = 20.97
# Geração 62: Min = 18.0, Avg = 21.33
# Geração 63: Min = 18.0, Avg = 20.61
# Geração 64: Min = 18.0, Avg = 21.23
# Geração 65: Min = 18.0, Avg = 21.07
# Geração 66: Min = 18.0, Avg = 19.74
# Geração 67: Min = 18.0, Avg = 19.74
# Geração 68: Min = 18.0, Avg = 20.08
# Geração 69: Min = 18.0, Avg = 20.24
# Geração 70: Min = 18.0, Avg = 19.69
# Geração 71: Min = 18.0, Avg = 19.78
# Geração 72: Min = 18.0, Avg = 19.34
# Geração 73: Min = 18.0, Avg = 19.26
# Geração 74: Min = 18.0, Avg = 20.54
# Geração 75: Min = 18.0, Avg = 19.56
# Geração 76: Min = 18.0, Avg = 20.45
# Geração 77: Min = 18.0, Avg = 20.65
# Geração 78: Min = 18.0, Avg = 21.15
# Geração 79: Min = 18.0, Avg = 20.22
# Geração 80: Min = 18.0, Avg = 21.0
# Geração 81: Min = 18.0, Avg = 19.66
# Geração 82: Min = 18.0, Avg = 19.9
# Geração 83: Min = 18.0, Avg = 20.78
# Geração 84: Min = 18.0, Avg = 20.2
# Geração 85: Min = 18.0, Avg = 20.25
# Geração 86: Min = 18.0, Avg = 20.24
# Geração 87: Min = 18.0, Avg = 20.55
# Geração 88: Min = 18.0, Avg = 18.9
# Geração 89: Min = 18.0, Avg = 21.32
# Geração 90: Min = 18.0, Avg = 19.77
# Geração 91: Min = 18.0, Avg = 21.25
# Geração 92: Min = 18.0, Avg = 21.37
# Geração 93: Min = 18.0, Avg = 19.89
# Geração 94: Min = 18.0, Avg = 20.46
# Geração 95: Min = 18.0, Avg = 19.63
# Geração 96: Min = 18.0, Avg = 19.73
# Geração 97: Min = 18.0, Avg = 19.98
# Geração 98: Min = 18.0, Avg = 20.19
# Geração 99: Min = 18.0, Avg = 20.44
# Média do número de bins: 17.6
# Melhor solução: [11, 34, 13, 18, 13, 32, 2, 34, 35, 12, 39, 32, 18, 20, 12, 28, 39, 13, 0, 8, 12, 47, 5, 4, 39, 35, 0, 12, 41, 8, 2, 41, 5, 2, 18, 47, 4, 2, 20, 28, 4, 5, 41, 20, 11, 49, 49, 49, 4, 8]
# Valor total: 18
# Peso total: 1452
# tamanho da Solução: 50

# %%
def fusao_bins(individuo):
    """Busca local: Fusão de Bins."""
    bins = {}  # Dicionário para armazenar os bins e seus pesos
    for i, bin_index in enumerate(individuo):
        if bin_index not in bins:
            bins[bin_index] = 0
        bins[bin_index] += pesos_itens[i]

    # Tentativa de fusão de bins
    bins_ids = list(bins.keys())
    for i in range(len(bins_ids)):
        for j in range(i + 1, len(bins_ids)):
            bin1_id = bins_ids[i]
            bin2_id = bins_ids[j]

            # Verificar se a fusão é possível
            if bins[bin1_id] + bins[bin2_id] <= CAPACIDADE_BIN:
                # Fundir os bins
                for k in range(len(individuo)):
                    if individuo[k] == bin2_id:
                        individuo[k] = bin1_id

                # Atualizar o dicionário de bins
                bins[bin1_id] += bins[bin2_id]
                del bins[bin2_id]

                # Retornar o indivíduo modificado
                return individuo,

    # Se nenhuma fusão foi possível, retornar o indivíduo original
    return individuo,

# %%
toolbox.register("f", fusao_bins)

# %%
def algoritmo_memetico(pop_size=100, ngen=100, p_cx=0.7, p_mut=0.2, p_local=0.3):
    """Executa um Algoritmo Memético com GA + Busca Local."""
    pop = toolbox.population(n=pop_size)
    hof = tools.HallOfFame(1)
    stats = tools.Statistics(lambda ind: ind.fitness.values)
    stats.register("min", np.min)
    stats.register("avg", np.mean)

    for gen in range(ngen):
        # Seleção e reprodução
        offspring = toolbox.select(pop, len(pop))
        offspring = list(map(toolbox.clone, offspring))

        for child1, child2 in zip(offspring[::2], offspring[1::2]):
            if random.random() < p_cx:
                toolbox.mate(child1, child2)
                del child1.fitness.values, child2.fitness.values

        for mutant in offspring:
            if random.random() < p_mut:
                toolbox.mutate(mutant)
                del mutant.fitness.values

        # Reavaliação dos filhos
        for ind in offspring:
            if not ind.fitness.valid:
                ind.fitness.values = toolbox.evaluate(ind)

        # Aplicação da busca local a uma fração da população
        for ind in random.sample(offspring, int(p_local * len(offspring))):
           toolbox.f(ind)
           ind.fitness.values = toolbox.evaluate(ind)

        pop[:] = offspring
        hof.update(pop)

        # Coleta estatísticas
        record = stats.compile(pop)
        print(f"Geração {gen}: Min = {record['min']}, Avg = {record['avg']}")

    return pop, hof

# %%
resultados = []
for i in range(10):
    pop, hof = algoritmo_memetico(pop_size=100, ngen=100, p_cx=0.7, p_mut=0.2, p_local=0.3)
    resultados.append(avaliar(hof[0])[0])  # Armazenar o número de bins


media_resultados = np.mean(resultados)
print("Média do número de bins:", media_resultados)
# Melhor solução encontrada
print("Melhor solução:", hof[0])
print("Valor total:", avaliar(hof[0])[0])
peso_total = 0
for bin_index in range(N_ITENS + 1): # Considerando todos os bins possíveis
    peso_bin = sum(pesos_itens[i] for i in range(N_ITENS) if hof[0][i] == bin_index)
    peso_total += peso_bin

print("Peso total:", peso_total)
print("tamanho da Solução:",len(hof[0]))
# Out:
# Geração 0: Min = 27.0, Avg = 44.19
# Geração 1: Min = 27.0, Avg = 40.25
# Geração 2: Min = 26.0, Avg = 37.86
# Geração 3: Min = 26.0, Avg = 36.26
# Geração 4: Min = 25.0, Avg = 36.39
# Geração 5: Min = 25.0, Avg = 33.71
# Geração 6: Min = 24.0, Avg = 32.76
# Geração 7: Min = 23.0, Avg = 29.57
# Geração 8: Min = 22.0, Avg = 28.31
# Geração 9: Min = 22.0, Avg = 25.96
# Geração 10: Min = 21.0, Avg = 25.45
# Geração 11: Min = 20.0, Avg = 24.45
# Geração 12: Min = 19.0, Avg = 23.74
# Geração 13: Min = 18.0, Avg = 23.66
# Geração 14: Min = 18.0, Avg = 23.26
# Geração 15: Min = 17.0, Avg = 22.26
# Geração 16: Min = 17.0, Avg = 21.2
# Geração 17: Min = 17.0, Avg = 22.04
# Geração 18: Min = 17.0, Avg = 21.57
# Geração 19: Min = 17.0, Avg = 22.22
# Geração 20: Min = 17.0, Avg = 21.72
# Geração 21: Min = 17.0, Avg = 20.65
# Geração 22: Min = 17.0, Avg = 21.31
# Geração 23: Min = 17.0, Avg = 21.17
# Geração 24: Min = 17.0, Avg = 20.63
# Geração 25: Min = 17.0, Avg = 19.26
# Geração 26: Min = 17.0, Avg = 19.75
# Geração 27: Min = 17.0, Avg = 21.0
# Geração 28: Min = 17.0, Avg = 20.76
# Geração 29: Min = 17.0, Avg = 19.52
# Geração 30: Min = 17.0, Avg = 20.13
# Geração 31: Min = 17.0, Avg = 19.53
# Geração 32: Min = 17.0, Avg = 19.87
# Geração 33: Min = 17.0, Avg = 18.01
# Geração 34: Min = 17.0, Avg = 20.13
# Geração 35: Min = 17.0, Avg = 19.3
# Geração 36: Min = 17.0, Avg = 20.41
# Geração 37: Min = 17.0, Avg = 19.46
# Geração 38: Min = 17.0, Avg = 19.27
# Geração 39: Min = 17.0, Avg = 19.13
# Geração 40: Min = 17.0, Avg = 19.97
# Geração 41: Min = 17.0, Avg = 19.04
# Geração 42: Min = 17.0, Avg = 18.8
# Geração 43: Min = 17.0, Avg = 18.97
# Geração 44: Min = 17.0, Avg = 20.05
# Geração 45: Min = 17.0, Avg = 19.65
# Geração 46: Min = 17.0, Avg = 20.14
# Geração 47: Min = 17.0, Avg = 18.89
# Geração 48: Min = 17.0, Avg = 20.14
# Geração 49: Min = 17.0, Avg = 19.02
# Geração 50: Min = 17.0, Avg = 19.48
# Geração 51: Min = 17.0, Avg = 18.77
# Geração 52: Min = 17.0, Avg = 20.04
# Geração 53: Min = 17.0, Avg = 19.94
# Geração 54: Min = 17.0, Avg = 20.04
# Geração 55: Min = 17.0, Avg = 18.96
# Geração 56: Min = 17.0, Avg = 19.02
# Geração 57: Min = 17.0, Avg = 19.85
# Geração 58: Min = 17.0, Avg = 19.91
# Geração 59: Min = 17.0, Avg = 19.37
# Geração 60: Min = 17.0, Avg = 19.99
# Geração 61: Min = 17.0, Avg = 19.69
# Geração 62: Min = 17.0, Avg = 19.55
# Geração 63: Min = 17.0, Avg = 20.58
# Geração 64: Min = 17.0, Avg = 19.24
# Geração 65: Min = 17.0, Avg = 20.14
# Geração 66: Min = 17.0, Avg = 19.59
# Geração 67: Min = 17.0, Avg = 20.01
# Geração 68: Min = 17.0, Avg = 19.35
# Geração 69: Min = 17.0, Avg = 20.3
# Geração 70: Min = 17.0, Avg = 20.01
# Geração 71: Min = 17.0, Avg = 19.16
# Geração 72: Min = 17.0, Avg = 19.62
# Geração 73: Min = 17.0, Avg = 19.58
# Geração 74: Min = 17.0, Avg = 20.22
# Geração 75: Min = 17.0, Avg = 19.87
# Geração 76: Min = 17.0, Avg = 19.43
# Geração 77: Min = 17.0, Avg = 19.26
# Geração 78: Min = 17.0, Avg = 19.8
# Geração 79: Min = 17.0, Avg = 19.21
# Geração 80: Min = 17.0, Avg = 19.24
# Geração 81: Min = 17.0, Avg = 19.69
# Geração 82: Min = 17.0, Avg = 19.45
# Geração 83: Min = 17.0, Avg = 19.57
# Geração 84: Min = 17.0, Avg = 20.5
# Geração 85: Min = 17.0, Avg = 19.39
# Geração 86: Min = 17.0, Avg = 19.89
# Geração 87: Min = 17.0, Avg = 19.49
# Geração 88: Min = 17.0, Avg = 19.33
# Geração 89: Min = 17.0, Avg = 20.08
# Geração 90: Min = 17.0, Avg = 19.57
# Geração 91: Min = 17.0, Avg = 19.14
# Geração 92: Min = 17.0, Avg = 18.58
# Geração 93: Min = 17.0, Avg = 19.93
# Geração 94: Min = 17.0, Avg = 18.63
# Geração 95: Min = 17.0, Avg = 20.12
# Geração 96: Min = 17.0, Avg = 20.3
# Geração 97: Min = 17.0, Avg = 19.45
# Geração 98: Min = 17.0, Avg = 19.35
# Geração 99: Min = 17.0, Avg = 19.16
# Geração 0: Min = 30.0, Avg = 46.94
# Geração 1: Min = 29.0, Avg = 39.88
# Geração 2: Min = 29.0, Avg = 38.61
# Geração 3: Min = 28.0, Avg = 35.78
# Geração 4: Min = 27.0, Avg = 36.46
# Geração 5: Min = 26.0, Avg = 36.32
# Geração 6: Min = 25.0, Avg = 35.92
# Geração 7: Min = 24.0, Avg = 35.22
# Geração 8: Min = 24.0, Avg = 33.12
# Geração 9: Min = 24.0, Avg = 33.81
# Geração 10: Min = 24.0, Avg = 35.59
# Geração 11: Min = 24.0, Avg = 32.67
# Geração 12: Min = 24.0, Avg = 35.53
# Geração 13: Min = 24.0, Avg = 35.08
# Geração 14: Min = 22.0, Avg = 33.91
# Geração 15: Min = 23.0, Avg = 32.91
# Geração 16: Min = 22.0, Avg = 30.47
# Geração 17: Min = 22.0, Avg = 29.86
# Geração 18: Min = 22.0, Avg = 28.99
# Geração 19: Min = 21.0, Avg = 29.37
# Geração 20: Min = 20.0, Avg = 27.97
# Geração 21: Min = 20.0, Avg = 27.13
# Geração 22: Min = 19.0, Avg = 25.77
# Geração 23: Min = 18.0, Avg = 26.32
# Geração 24: Min = 17.0, Avg = 25.57
# Geração 25: Min = 17.0, Avg = 24.86
# Geração 26: Min = 17.0, Avg = 24.19
# Geração 27: Min = 17.0, Avg = 24.65
# Geração 28: Min = 17.0, Avg = 25.59
# Geração 29: Min = 17.0, Avg = 26.93
# Geração 30: Min = 17.0, Avg = 26.73
# Geração 31: Min = 17.0, Avg = 24.5
# Geração 32: Min = 17.0, Avg = 24.24
# Geração 33: Min = 17.0, Avg = 24.18
# Geração 34: Min = 16.0, Avg = 21.68
# Geração 35: Min = 16.0, Avg = 20.11
# Geração 36: Min = 17.0, Avg = 20.26
# Geração 37: Min = 17.0, Avg = 18.95
# Geração 38: Min = 17.0, Avg = 19.19
# Geração 39: Min = 17.0, Avg = 19.76
# Geração 40: Min = 17.0, Avg = 19.51
# Geração 41: Min = 17.0, Avg = 20.06
# Geração 42: Min = 17.0, Avg = 20.54
# Geração 43: Min = 17.0, Avg = 19.73
# Geração 44: Min = 17.0, Avg = 19.49
# Geração 45: Min = 17.0, Avg = 20.28
# Geração 46: Min = 17.0, Avg = 18.84
# Geração 47: Min = 17.0, Avg = 21.03
# Geração 48: Min = 17.0, Avg = 19.55
# Geração 49: Min = 17.0, Avg = 18.06
# Geração 50: Min = 17.0, Avg = 19.96
# Geração 51: Min = 17.0, Avg = 19.86
# Geração 52: Min = 17.0, Avg = 19.47
# Geração 53: Min = 17.0, Avg = 19.36
# Geração 54: Min = 17.0, Avg = 19.06
# Geração 55: Min = 17.0, Avg = 18.76
# Geração 56: Min = 17.0, Avg = 19.89
# Geração 57: Min = 17.0, Avg = 19.8
# Geração 58: Min = 17.0, Avg = 19.3
# Geração 59: Min = 17.0, Avg = 18.81
# Geração 60: Min = 17.0, Avg = 19.82
# Geração 61: Min = 17.0, Avg = 20.7
# Geração 62: Min = 17.0, Avg = 20.44
# Geração 63: Min = 17.0, Avg = 19.3
# Geração 64: Min = 17.0, Avg = 20.32
# Geração 65: Min = 17.0, Avg = 19.37
# Geração 66: Min = 17.0, Avg = 18.08
# Geração 67: Min = 17.0, Avg = 18.81
# Geração 68: Min = 17.0, Avg = 19.66
# Geração 69: Min = 17.0, Avg = 19.52
# Geração 70: Min = 17.0, Avg = 19.98
# Geração 71: Min = 17.0, Avg = 19.56
# Geração 72: Min = 17.0, Avg = 18.62
# Geração 73: Min = 17.0, Avg = 19.89
# Geração 74: Min = 17.0, Avg = 19.42
# Geração 75: Min = 17.0, Avg = 20.32
# Geração 76: Min = 17.0, Avg = 19.94
# Geração 77: Min = 17.0, Avg = 21.02
# Geração 78: Min = 17.0, Avg = 19.68
# Geração 79: Min = 17.0, Avg = 20.13
# Geração 80: Min = 17.0, Avg = 18.19
# Geração 81: Min = 17.0, Avg = 20.45
# Geração 82: Min = 17.0, Avg = 19.69
# Geração 83: Min = 17.0, Avg = 19.45
# Geração 84: Min = 17.0, Avg = 19.93
# Geração 85: Min = 17.0, Avg = 19.57
# Geração 86: Min = 17.0, Avg = 20.34
# Geração 87: Min = 17.0, Avg = 19.49
# Geração 88: Min = 17.0, Avg = 19.31
# Geração 89: Min = 17.0, Avg = 20.45
# Geração 90: Min = 17.0, Avg = 19.73
# Geração 91: Min = 17.0, Avg = 20.05
# Geração 92: Min = 17.0, Avg = 18.18
# Geração 93: Min = 17.0, Avg = 18.96
# Geração 94: Min = 17.0, Avg = 18.53
# Geração 95: Min = 17.0, Avg = 18.79
# Geração 96: Min = 17.0, Avg = 18.69
# Geração 97: Min = 17.0, Avg = 18.8
# Geração 98: Min = 17.0, Avg = 18.16
# Geração 99: Min = 17.0, Avg = 19.76
# Geração 0: Min = 30.0, Avg = 44.74
# Geração 1: Min = 29.0, Avg = 40.52
# Geração 2: Min = 28.0, Avg = 39.04
# Geração 3: Min = 27.0, Avg = 37.38
# Geração 4: Min = 25.0, Avg = 37.17
# Geração 5: Min = 24.0, Avg = 35.66
# Geração 6: Min = 25.0, Avg = 36.45
# Geração 7: Min = 24.0, Avg = 36.74
# Geração 8: Min = 23.0, Avg = 35.51
# Geração 9: Min = 23.0, Avg = 34.61
# Geração 10: Min = 23.0, Avg = 33.76
# Geração 11: Min = 23.0, Avg = 30.38
# Geração 12: Min = 22.0, Avg = 29.21
# Geração 13: Min = 21.0, Avg = 29.22
# Geração 14: Min = 21.0, Avg = 26.94
# Geração 15: Min = 20.0, Avg = 25.67
# Geração 16: Min = 19.0, Avg = 25.72
# Geração 17: Min = 19.0, Avg = 24.77
# Geração 18: Min = 19.0, Avg = 23.01
# Geração 19: Min = 18.0, Avg = 22.31
# Geração 20: Min = 17.0, Avg = 21.62
# Geração 21: Min = 16.0, Avg = 19.49
# Geração 22: Min = 16.0, Avg = 19.39
# Geração 23: Min = 16.0, Avg = 19.53
# Geração 24: Min = 16.0, Avg = 18.98
# Geração 25: Min = 16.0, Avg = 18.59
# Geração 26: Min = 16.0, Avg = 18.97
# Geração 27: Min = 16.0, Avg = 18.96
# Geração 28: Min = 16.0, Avg = 18.49
# Geração 29: Min = 16.0, Avg = 18.58
# Geração 30: Min = 16.0, Avg = 18.45
# Geração 31: Min = 16.0, Avg = 17.94
# Geração 32: Min = 16.0, Avg = 18.64
# Geração 33: Min = 16.0, Avg = 18.39
# Geração 34: Min = 16.0, Avg = 18.4
# Geração 35: Min = 16.0, Avg = 19.89
# Geração 36: Min = 16.0, Avg = 18.84
# Geração 37: Min = 16.0, Avg = 20.85
# Geração 38: Min = 16.0, Avg = 19.67
# Geração 39: Min = 16.0, Avg = 19.09
# Geração 40: Min = 16.0, Avg = 20.44
# Geração 41: Min = 16.0, Avg = 18.48
# Geração 42: Min = 16.0, Avg = 19.02
# Geração 43: Min = 16.0, Avg = 17.9
# Geração 44: Min = 16.0, Avg = 19.1
# Geração 45: Min = 16.0, Avg = 18.36
# Geração 46: Min = 16.0, Avg = 18.29
# Geração 47: Min = 16.0, Avg = 18.46
# Geração 48: Min = 16.0, Avg = 18.57
# Geração 49: Min = 16.0, Avg = 17.69
# Geração 50: Min = 16.0, Avg = 18.25
# Geração 51: Min = 16.0, Avg = 18.19
# Geração 52: Min = 16.0, Avg = 18.75
# Geração 53: Min = 16.0, Avg = 18.91
# Geração 54: Min = 16.0, Avg = 19.06
# Geração 55: Min = 16.0, Avg = 17.75
# Geração 56: Min = 16.0, Avg = 18.88
# Geração 57: Min = 16.0, Avg = 18.81
# Geração 58: Min = 16.0, Avg = 17.74
# Geração 59: Min = 16.0, Avg = 18.6
# Geração 60: Min = 16.0, Avg = 19.38
# Geração 61: Min = 16.0, Avg = 19.25
# Geração 62: Min = 16.0, Avg = 18.32
# Geração 63: Min = 16.0, Avg = 18.78
# Geração 64: Min = 16.0, Avg = 20.27
# Geração 65: Min = 16.0, Avg = 18.5
# Geração 66: Min = 16.0, Avg = 18.63
# Geração 67: Min = 16.0, Avg = 18.88
# Geração 68: Min = 16.0, Avg = 20.87
# Geração 69: Min = 16.0, Avg = 19.0
# Geração 70: Min = 16.0, Avg = 19.24
# Geração 71: Min = 16.0, Avg = 18.29
# Geração 72: Min = 16.0, Avg = 19.6
# Geração 73: Min = 16.0, Avg = 18.61
# Geração 74: Min = 16.0, Avg = 17.91
# Geração 75: Min = 16.0, Avg = 19.62
# Geração 76: Min = 16.0, Avg = 18.4
# Geração 77: Min = 16.0, Avg = 18.21
# Geração 78: Min = 16.0, Avg = 18.66
# Geração 79: Min = 16.0, Avg = 18.73
# Geração 80: Min = 16.0, Avg = 18.94
# Geração 81: Min = 16.0, Avg = 19.01
# Geração 82: Min = 16.0, Avg = 18.06
# Geração 83: Min = 16.0, Avg = 19.26
# Geração 84: Min = 16.0, Avg = 18.35
# Geração 85: Min = 16.0, Avg = 18.91
# Geração 86: Min = 16.0, Avg = 19.85
# Geração 87: Min = 16.0, Avg = 18.8
# Geração 88: Min = 16.0, Avg = 18.37
# Geração 89: Min = 16.0, Avg = 17.65
# Geração 90: Min = 16.0, Avg = 19.08
# Geração 91: Min = 16.0, Avg = 18.26
# Geração 92: Min = 16.0, Avg = 18.81
# Geração 93: Min = 16.0, Avg = 18.0
# Geração 94: Min = 16.0, Avg = 18.26
# Geração 95: Min = 16.0, Avg = 17.24
# Geração 96: Min = 16.0, Avg = 18.27
# Geração 97: Min = 16.0, Avg = 19.21
# Geração 98: Min = 16.0, Avg = 18.15
# Geração 99: Min = 16.0, Avg = 19.06
# Geração 0: Min = 29.0, Avg = 45.21
# Geração 1: Min = 28.0, Avg = 40.95
# Geração 2: Min = 26.0, Avg = 37.5
# Geração 3: Min = 26.0, Avg = 38.39
# Geração 4: Min = 27.0, Avg = 36.2
# Geração 5: Min = 27.0, Avg = 35.6
# Geração 6: Min = 26.0, Avg = 37.9
# Geração 7: Min = 26.0, Avg = 35.38
# Geração 8: Min = 26.0, Avg = 36.93
# Geração 9: Min = 26.0, Avg = 35.52
# Geração 10: Min = 25.0, Avg = 36.52
# Geração 11: Min = 24.0, Avg = 36.08
# Geração 12: Min = 25.0, Avg = 36.33
# Geração 13: Min = 25.0, Avg = 34.35
# Geração 14: Min = 24.0, Avg = 32.4
# Geração 15: Min = 23.0, Avg = 31.83
# Geração 16: Min = 22.0, Avg = 28.03
# Geração 17: Min = 22.0, Avg = 26.37
# Geração 18: Min = 21.0, Avg = 25.55
# Geração 19: Min = 20.0, Avg = 24.38
# Geração 20: Min = 20.0, Avg = 22.62
# Geração 21: Min = 19.0, Avg = 21.6
# Geração 22: Min = 18.0, Avg = 22.47
# Geração 23: Min = 17.0, Avg = 22.29
# Geração 24: Min = 16.0, Avg = 20.1
# Geração 25: Min = 16.0, Avg = 20.12
# Geração 26: Min = 16.0, Avg = 17.55
# Geração 27: Min = 16.0, Avg = 19.52
# Geração 28: Min = 16.0, Avg = 19.8
# Geração 29: Min = 16.0, Avg = 18.96
# Geração 30: Min = 16.0, Avg = 18.17
# Geração 31: Min = 16.0, Avg = 18.27
# Geração 32: Min = 16.0, Avg = 18.71
# Geração 33: Min = 16.0, Avg = 19.76
# Geração 34: Min = 16.0, Avg = 17.93
# Geração 35: Min = 16.0, Avg = 19.03
# Geração 36: Min = 16.0, Avg = 18.58
# Geração 37: Min = 16.0, Avg = 18.86
# Geração 38: Min = 16.0, Avg = 17.91
# Geração 39: Min = 16.0, Avg = 19.54
# Geração 40: Min = 16.0, Avg = 18.35
# Geração 41: Min = 16.0, Avg = 18.58
# Geração 42: Min = 16.0, Avg = 18.85
# Geração 43: Min = 16.0, Avg = 18.62
# Geração 44: Min = 16.0, Avg = 17.58
# Geração 45: Min = 16.0, Avg = 18.89
# Geração 46: Min = 16.0, Avg = 18.43
# Geração 47: Min = 16.0, Avg = 17.18
# Geração 48: Min = 16.0, Avg = 18.13
# Geração 49: Min = 16.0, Avg = 19.23
# Geração 50: Min = 16.0, Avg = 19.24
# Geração 51: Min = 16.0, Avg = 18.53
# Geração 52: Min = 16.0, Avg = 18.34
# Geração 53: Min = 16.0, Avg = 18.9
# Geração 54: Min = 16.0, Avg = 21.5
# Geração 55: Min = 16.0, Avg = 18.92
# Geração 56: Min = 16.0, Avg = 19.29
# Geração 57: Min = 16.0, Avg = 19.75
# Geração 58: Min = 16.0, Avg = 19.74
# Geração 59: Min = 16.0, Avg = 18.45
# Geração 60: Min = 16.0, Avg = 19.15
# Geração 61: Min = 16.0, Avg = 18.55
# Geração 62: Min = 16.0, Avg = 18.66
# Geração 63: Min = 16.0, Avg = 17.38
# Geração 64: Min = 16.0, Avg = 18.25
# Geração 65: Min = 16.0, Avg = 18.42
# Geração 66: Min = 16.0, Avg = 18.29
# Geração 67: Min = 16.0, Avg = 18.2
# Geração 68: Min = 16.0, Avg = 17.97
# Geração 69: Min = 16.0, Avg = 20.05
# Geração 70: Min = 16.0, Avg = 19.36
# Geração 71: Min = 16.0, Avg = 19.31
# Geração 72: Min = 16.0, Avg = 18.95
# Geração 73: Min = 16.0, Avg = 19.64
# Geração 74: Min = 16.0, Avg = 17.76
# Geração 75: Min = 16.0, Avg = 19.3
# Geração 76: Min = 16.0, Avg = 19.15
# Geração 77: Min = 16.0, Avg = 18.4
# Geração 78: Min = 16.0, Avg = 17.6
# Geração 79: Min = 16.0, Avg = 19.5
# Geração 80: Min = 16.0, Avg = 19.87
# Geração 81: Min = 16.0, Avg = 18.55
# Geração 82: Min = 16.0, Avg = 18.84
# Geração 83: Min = 16.0, Avg = 18.42
# Geração 84: Min = 16.0, Avg = 18.71
# Geração 85: Min = 16.0, Avg = 18.26
# Geração 86: Min = 16.0, Avg = 19.15
# Geração 87: Min = 16.0, Avg = 18.44
# Geração 88: Min = 16.0, Avg = 19.65
# Geração 89: Min = 16.0, Avg = 19.0
# Geração 90: Min = 16.0, Avg = 18.12
# Geração 91: Min = 16.0, Avg = 19.44
# Geração 92: Min = 16.0, Avg = 18.3
# Geração 93: Min = 16.0, Avg = 17.78
# Geração 94: Min = 16.0, Avg = 17.51
# Geração 95: Min = 16.0, Avg = 19.0
# Geração 96: Min = 16.0, Avg = 19.7
# Geração 97: Min = 16.0, Avg = 18.73
# Geração 98: Min = 16.0, Avg = 17.87
# Geração 99: Min = 16.0, Avg = 18.25
# Geração 0: Min = 29.0, Avg = 43.15
# Geração 1: Min = 29.0, Avg = 39.26
# Geração 2: Min = 28.0, Avg = 37.33
# Geração 3: Min = 27.0, Avg = 36.81
# Geração 4: Min = 25.0, Avg = 38.68
# Geração 5: Min = 24.0, Avg = 37.31
# Geração 6: Min = 23.0, Avg = 35.61
# Geração 7: Min = 23.0, Avg = 34.61
# Geração 8: Min = 22.0, Avg = 32.5
# Geração 9: Min = 22.0, Avg = 33.26
# Geração 10: Min = 22.0, Avg = 30.03
# Geração 11: Min = 21.0, Avg = 27.63
# Geração 12: Min = 20.0, Avg = 25.44
# Geração 13: Min = 20.0, Avg = 24.83
# Geração 14: Min = 19.0, Avg = 25.37
# Geração 15: Min = 18.0, Avg = 24.2
# Geração 16: Min = 18.0, Avg = 23.99
# Geração 17: Min = 17.0, Avg = 23.43
# Geração 18: Min = 17.0, Avg = 21.97
# Geração 19: Min = 17.0, Avg = 21.0
# Geração 20: Min = 17.0, Avg = 21.13
# Geração 21: Min = 17.0, Avg = 19.85
# Geração 22: Min = 17.0, Avg = 18.93
# Geração 23: Min = 17.0, Avg = 18.85
# Geração 24: Min = 17.0, Avg = 18.87
# Geração 25: Min = 17.0, Avg = 20.43
# Geração 26: Min = 17.0, Avg = 19.35
# Geração 27: Min = 17.0, Avg = 19.86
# Geração 28: Min = 17.0, Avg = 18.57
# Geração 29: Min = 17.0, Avg = 19.62
# Geração 30: Min = 17.0, Avg = 19.84
# Geração 31: Min = 17.0, Avg = 19.68
# Geração 32: Min = 17.0, Avg = 19.94
# Geração 33: Min = 17.0, Avg = 19.22
# Geração 34: Min = 17.0, Avg = 19.41
# Geração 35: Min = 17.0, Avg = 19.08
# Geração 36: Min = 17.0, Avg = 19.06
# Geração 37: Min = 17.0, Avg = 19.45
# Geração 38: Min = 17.0, Avg = 20.01
# Geração 39: Min = 17.0, Avg = 19.92
# Geração 40: Min = 17.0, Avg = 19.24
# Geração 41: Min = 17.0, Avg = 18.82
# Geração 42: Min = 17.0, Avg = 19.12
# Geração 43: Min = 17.0, Avg = 21.16
# Geração 44: Min = 17.0, Avg = 19.84
# Geração 45: Min = 17.0, Avg = 19.29
# Geração 46: Min = 17.0, Avg = 18.97
# Geração 47: Min = 17.0, Avg = 19.21
# Geração 48: Min = 17.0, Avg = 19.42
# Geração 49: Min = 17.0, Avg = 18.63
# Geração 50: Min = 17.0, Avg = 19.8
# Geração 51: Min = 17.0, Avg = 20.27
# Geração 52: Min = 17.0, Avg = 20.21
# Geração 53: Min = 17.0, Avg = 20.36
# Geração 54: Min = 17.0, Avg = 19.04
# Geração 55: Min = 17.0, Avg = 19.3
# Geração 56: Min = 17.0, Avg = 20.25
# Geração 57: Min = 17.0, Avg = 20.26
# Geração 58: Min = 17.0, Avg = 19.79
# Geração 59: Min = 17.0, Avg = 19.75
# Geração 60: Min = 17.0, Avg = 19.84
# Geração 61: Min = 17.0, Avg = 19.43
# Geração 62: Min = 17.0, Avg = 20.3
# Geração 63: Min = 17.0, Avg = 19.87
# Geração 64: Min = 17.0, Avg = 19.0
# Geração 65: Min = 17.0, Avg = 20.09
# Geração 66: Min = 17.0, Avg = 18.59
# Geração 67: Min = 17.0, Avg = 18.92
# Geração 68: Min = 17.0, Avg = 19.29
# Geração 69: Min = 17.0, Avg = 19.53
# Geração 70: Min = 17.0, Avg = 20.09
# Geração 71: Min = 17.0, Avg = 20.24
# Geração 72: Min = 17.0, Avg = 18.7
# Geração 73: Min = 17.0, Avg = 19.76
# Geração 74: Min = 17.0, Avg = 19.48
# Geração 75: Min = 17.0, Avg = 19.77
# Geração 76: Min = 17.0, Avg = 18.5
# Geração 77: Min = 17.0, Avg = 19.43
# Geração 78: Min = 17.0, Avg = 19.28
# Geração 79: Min = 17.0, Avg = 19.24
# Geração 80: Min = 17.0, Avg = 19.14
# Geração 81: Min = 17.0, Avg = 19.12
# Geração 82: Min = 16.0, Avg = 20.31
# Geração 83: Min = 17.0, Avg = 20.7
# Geração 84: Min = 17.0, Avg = 18.59
# Geração 85: Min = 17.0, Avg = 20.09
# Geração 86: Min = 17.0, Avg = 19.66
# Geração 87: Min = 17.0, Avg = 20.95
# Geração 88: Min = 17.0, Avg = 19.21
# Geração 89: Min = 16.0, Avg = 19.22
# Geração 90: Min = 17.0, Avg = 20.55
# Geração 91: Min = 17.0, Avg = 19.93
# Geração 92: Min = 17.0, Avg = 19.4
# Geração 93: Min = 17.0, Avg = 19.76
# Geração 94: Min = 17.0, Avg = 20.09
# Geração 95: Min = 17.0, Avg = 19.74
# Geração 96: Min = 17.0, Avg = 18.7
# Geração 97: Min = 17.0, Avg = 19.67
# Geração 98: Min = 17.0, Avg = 19.36
# Geração 99: Min = 17.0, Avg = 18.67
# Geração 0: Min = 29.0, Avg = 46.2
# Geração 1: Min = 30.0, Avg = 42.21
# Geração 2: Min = 29.0, Avg = 39.29
# Geração 3: Min = 28.0, Avg = 37.75
# Geração 4: Min = 27.0, Avg = 38.42
# Geração 5: Min = 27.0, Avg = 36.48
# Geração 6: Min = 27.0, Avg = 36.57
# Geração 7: Min = 26.0, Avg = 35.27
# Geração 8: Min = 25.0, Avg = 34.71
# Geração 9: Min = 24.0, Avg = 35.03
# Geração 10: Min = 23.0, Avg = 34.41
# Geração 11: Min = 22.0, Avg = 34.96
# Geração 12: Min = 21.0, Avg = 32.91
# Geração 13: Min = 20.0, Avg = 32.99
# Geração 14: Min = 19.0, Avg = 32.1
# Geração 15: Min = 19.0, Avg = 30.14
# Geração 16: Min = 18.0, Avg = 30.99
# Geração 17: Min = 18.0, Avg = 30.4
# Geração 18: Min = 17.0, Avg = 25.29
# Geração 19: Min = 17.0, Avg = 22.41
# Geração 20: Min = 17.0, Avg = 20.87
# Geração 21: Min = 16.0, Avg = 21.13
# Geração 22: Min = 16.0, Avg = 19.68
# Geração 23: Min = 16.0, Avg = 19.32
# Geração 24: Min = 16.0, Avg = 19.8
# Geração 25: Min = 16.0, Avg = 20.31
# Geração 26: Min = 16.0, Avg = 18.98
# Geração 27: Min = 16.0, Avg = 19.95
# Geração 28: Min = 16.0, Avg = 19.89
# Geração 29: Min = 16.0, Avg = 18.87
# Geração 30: Min = 16.0, Avg = 20.23
# Geração 31: Min = 16.0, Avg = 19.3
# Geração 32: Min = 16.0, Avg = 18.21
# Geração 33: Min = 16.0, Avg = 18.73
# Geração 34: Min = 16.0, Avg = 18.28
# Geração 35: Min = 16.0, Avg = 17.93
# Geração 36: Min = 16.0, Avg = 18.74
# Geração 37: Min = 16.0, Avg = 18.6
# Geração 38: Min = 16.0, Avg = 18.28
# Geração 39: Min = 16.0, Avg = 20.2
# Geração 40: Min = 16.0, Avg = 18.88
# Geração 41: Min = 16.0, Avg = 19.48
# Geração 42: Min = 16.0, Avg = 18.26
# Geração 43: Min = 16.0, Avg = 19.6
# Geração 44: Min = 16.0, Avg = 19.69
# Geração 45: Min = 16.0, Avg = 18.7
# Geração 46: Min = 16.0, Avg = 18.92
# Geração 47: Min = 16.0, Avg = 17.78
# Geração 48: Min = 16.0, Avg = 18.52
# Geração 49: Min = 16.0, Avg = 19.83
# Geração 50: Min = 16.0, Avg = 20.46
# Geração 51: Min = 16.0, Avg = 18.91
# Geração 52: Min = 16.0, Avg = 19.36
# Geração 53: Min = 16.0, Avg = 18.8
# Geração 54: Min = 16.0, Avg = 19.13
# Geração 55: Min = 16.0, Avg = 19.18
# Geração 56: Min = 16.0, Avg = 18.55
# Geração 57: Min = 16.0, Avg = 17.92
# Geração 58: Min = 16.0, Avg = 21.37
# Geração 59: Min = 16.0, Avg = 18.74
# Geração 60: Min = 16.0, Avg = 18.93
# Geração 61: Min = 16.0, Avg = 19.5
# Geração 62: Min = 16.0, Avg = 17.63
# Geração 63: Min = 16.0, Avg = 19.01
# Geração 64: Min = 16.0, Avg = 18.51
# Geração 65: Min = 16.0, Avg = 18.71
# Geração 66: Min = 16.0, Avg = 20.07
# Geração 67: Min = 16.0, Avg = 18.9
# Geração 68: Min = 16.0, Avg = 18.33
# Geração 69: Min = 16.0, Avg = 19.65
# Geração 70: Min = 16.0, Avg = 18.45
# Geração 71: Min = 16.0, Avg = 18.58
# Geração 72: Min = 16.0, Avg = 18.34
# Geração 73: Min = 16.0, Avg = 20.17
# Geração 74: Min = 16.0, Avg = 18.88
# Geração 75: Min = 16.0, Avg = 18.55
# Geração 76: Min = 16.0, Avg = 18.31
# Geração 77: Min = 16.0, Avg = 18.99
# Geração 78: Min = 16.0, Avg = 18.7
# Geração 79: Min = 16.0, Avg = 18.27
# Geração 80: Min = 16.0, Avg = 17.01
# Geração 81: Min = 16.0, Avg = 18.14
# Geração 82: Min = 16.0, Avg = 19.57
# Geração 83: Min = 16.0, Avg = 18.91
# Geração 84: Min = 16.0, Avg = 19.03
# Geração 85: Min = 16.0, Avg = 18.67
# Geração 86: Min = 16.0, Avg = 18.1
# Geração 87: Min = 16.0, Avg = 18.28
# Geração 88: Min = 16.0, Avg = 18.54
# Geração 89: Min = 16.0, Avg = 18.68
# Geração 90: Min = 16.0, Avg = 19.18
# Geração 91: Min = 16.0, Avg = 18.38
# Geração 92: Min = 16.0, Avg = 18.75
# Geração 93: Min = 16.0, Avg = 20.21
# Geração 94: Min = 16.0, Avg = 18.82
# Geração 95: Min = 16.0, Avg = 19.54
# Geração 96: Min = 16.0, Avg = 18.85
# Geração 97: Min = 16.0, Avg = 19.99
# Geração 98: Min = 16.0, Avg = 18.79
# Geração 99: Min = 16.0, Avg = 18.36
# Geração 0: Min = 30.0, Avg = 45.52
# Geração 1: Min = 29.0, Avg = 41.54
# Geração 2: Min = 29.0, Avg = 39.64
# Geração 3: Min = 28.0, Avg = 36.93
# Geração 4: Min = 29.0, Avg = 37.72
# Geração 5: Min = 28.0, Avg = 38.74
# Geração 6: Min = 26.0, Avg = 36.93
# Geração 7: Min = 28.0, Avg = 36.32
# Geração 8: Min = 28.0, Avg = 34.59
# Geração 9: Min = 27.0, Avg = 36.6
# Geração 10: Min = 26.0, Avg = 36.91
# Geração 11: Min = 26.0, Avg = 34.96
# Geração 12: Min = 25.0, Avg = 31.85
# Geração 13: Min = 24.0, Avg = 30.61
# Geração 14: Min = 23.0, Avg = 30.21
# Geração 15: Min = 23.0, Avg = 30.08
# Geração 16: Min = 22.0, Avg = 28.82
# Geração 17: Min = 22.0, Avg = 29.05
# Geração 18: Min = 22.0, Avg = 28.87
# Geração 19: Min = 21.0, Avg = 26.66
# Geração 20: Min = 21.0, Avg = 26.64
# Geração 21: Min = 20.0, Avg = 27.54
# Geração 22: Min = 19.0, Avg = 26.92
# Geração 23: Min = 18.0, Avg = 24.35
# Geração 24: Min = 18.0, Avg = 26.75
# Geração 25: Min = 17.0, Avg = 25.73
# Geração 26: Min = 17.0, Avg = 24.04
# Geração 27: Min = 16.0, Avg = 23.83
# Geração 28: Min = 16.0, Avg = 22.65
# Geração 29: Min = 16.0, Avg = 21.95
# Geração 30: Min = 16.0, Avg = 22.21
# Geração 31: Min = 16.0, Avg = 22.63
# Geração 32: Min = 16.0, Avg = 21.05
# Geração 33: Min = 16.0, Avg = 21.05
# Geração 34: Min = 16.0, Avg = 20.01
# Geração 35: Min = 16.0, Avg = 19.46
# Geração 36: Min = 16.0, Avg = 20.52
# Geração 37: Min = 16.0, Avg = 18.36
# Geração 38: Min = 16.0, Avg = 19.0
# Geração 39: Min = 16.0, Avg = 17.52
# Geração 40: Min = 16.0, Avg = 19.86
# Geração 41: Min = 16.0, Avg = 19.32
# Geração 42: Min = 16.0, Avg = 18.68
# Geração 43: Min = 16.0, Avg = 18.4
# Geração 44: Min = 16.0, Avg = 19.21
# Geração 45: Min = 16.0, Avg = 19.4
# Geração 46: Min = 16.0, Avg = 17.55
# Geração 47: Min = 16.0, Avg = 18.46
# Geração 48: Min = 16.0, Avg = 17.67
# Geração 49: Min = 16.0, Avg = 19.0
# Geração 50: Min = 16.0, Avg = 19.07
# Geração 51: Min = 16.0, Avg = 18.34
# Geração 52: Min = 16.0, Avg = 19.27
# Geração 53: Min = 16.0, Avg = 19.08
# Geração 54: Min = 16.0, Avg = 19.11
# Geração 55: Min = 16.0, Avg = 17.86
# Geração 56: Min = 16.0, Avg = 20.08
# Geração 57: Min = 16.0, Avg = 18.34
# Geração 58: Min = 16.0, Avg = 18.73
# Geração 59: Min = 16.0, Avg = 19.46
# Geração 60: Min = 16.0, Avg = 18.17
# Geração 61: Min = 16.0, Avg = 18.64
# Geração 62: Min = 16.0, Avg = 18.47
# Geração 63: Min = 16.0, Avg = 18.01
# Geração 64: Min = 16.0, Avg = 18.26
# Geração 65: Min = 16.0, Avg = 17.78
# Geração 66: Min = 16.0, Avg = 18.62
# Geração 67: Min = 16.0, Avg = 19.08
# Geração 68: Min = 16.0, Avg = 18.77
# Geração 69: Min = 16.0, Avg = 17.69
# Geração 70: Min = 16.0, Avg = 19.72
# Geração 71: Min = 16.0, Avg = 18.31
# Geração 72: Min = 16.0, Avg = 19.03
# Geração 73: Min = 16.0, Avg = 19.14
# Geração 74: Min = 16.0, Avg = 19.87
# Geração 75: Min = 16.0, Avg = 18.22
# Geração 76: Min = 16.0, Avg = 18.5
# Geração 77: Min = 16.0, Avg = 19.12
# Geração 78: Min = 16.0, Avg = 18.79
# Geração 79: Min = 16.0, Avg = 18.83
# Geração 80: Min = 16.0, Avg = 19.37
# Geração 81: Min = 16.0, Avg = 18.3
# Geração 82: Min = 16.0, Avg = 18.87
# Geração 83: Min = 16.0, Avg = 18.55
# Geração 84: Min = 16.0, Avg = 17.87
# Geração 85: Min = 16.0, Avg = 19.13
# Geração 86: Min = 16.0, Avg = 19.3
# Geração 87: Min = 16.0, Avg = 19.28
# Geração 88: Min = 16.0, Avg = 18.82
# Geração 89: Min = 16.0, Avg = 17.9
# Geração 90: Min = 16.0, Avg = 17.93
# Geração 91: Min = 16.0, Avg = 18.65
# Geração 92: Min = 16.0, Avg = 18.15
# Geração 93: Min = 16.0, Avg = 17.59
# Geração 94: Min = 16.0, Avg = 18.62
# Geração 95: Min = 16.0, Avg = 17.98
# Geração 96: Min = 16.0, Avg = 18.75
# Geração 97: Min = 16.0, Avg = 18.75
# Geração 98: Min = 16.0, Avg = 18.03
# Geração 99: Min = 16.0, Avg = 19.46
# Geração 0: Min = 30.0, Avg = 46.57
# Geração 1: Min = 28.0, Avg = 41.34
# Geração 2: Min = 28.0, Avg = 39.98
# Geração 3: Min = 28.0, Avg = 38.12
# Geração 4: Min = 28.0, Avg = 35.84
# Geração 5: Min = 27.0, Avg = 37.43
# Geração 6: Min = 26.0, Avg = 37.23
# Geração 7: Min = 26.0, Avg = 34.21
# Geração 8: Min = 26.0, Avg = 34.76
# Geração 9: Min = 25.0, Avg = 36.37
# Geração 10: Min = 25.0, Avg = 36.36
# Geração 11: Min = 23.0, Avg = 35.5
# Geração 12: Min = 22.0, Avg = 34.53
# Geração 13: Min = 22.0, Avg = 33.64
# Geração 14: Min = 21.0, Avg = 32.21
# Geração 15: Min = 20.0, Avg = 31.63
# Geração 16: Min = 20.0, Avg = 31.49
# Geração 17: Min = 19.0, Avg = 31.97
# Geração 18: Min = 18.0, Avg = 31.0
# Geração 19: Min = 18.0, Avg = 29.34
# Geração 20: Min = 18.0, Avg = 28.4
# Geração 21: Min = 18.0, Avg = 25.9
# Geração 22: Min = 18.0, Avg = 23.26
# Geração 23: Min = 18.0, Avg = 23.11
# Geração 24: Min = 18.0, Avg = 23.55
# Geração 25: Min = 18.0, Avg = 22.56
# Geração 26: Min = 18.0, Avg = 22.21
# Geração 27: Min = 18.0, Avg = 22.41
# Geração 28: Min = 18.0, Avg = 20.7
# Geração 29: Min = 18.0, Avg = 21.59
# Geração 30: Min = 18.0, Avg = 22.06
# Geração 31: Min = 18.0, Avg = 21.3
# Geração 32: Min = 18.0, Avg = 21.29
# Geração 33: Min = 18.0, Avg = 21.68
# Geração 34: Min = 18.0, Avg = 21.74
# Geração 35: Min = 18.0, Avg = 20.7
# Geração 36: Min = 18.0, Avg = 20.56
# Geração 37: Min = 18.0, Avg = 21.17
# Geração 38: Min = 18.0, Avg = 21.16
# Geração 39: Min = 17.0, Avg = 20.28
# Geração 40: Min = 17.0, Avg = 19.75
# Geração 41: Min = 17.0, Avg = 20.25
# Geração 42: Min = 17.0, Avg = 19.95
# Geração 43: Min = 16.0, Avg = 20.76
# Geração 44: Min = 16.0, Avg = 20.24
# Geração 45: Min = 16.0, Avg = 20.92
# Geração 46: Min = 17.0, Avg = 19.73
# Geração 47: Min = 17.0, Avg = 20.73
# Geração 48: Min = 16.0, Avg = 20.68
# Geração 49: Min = 16.0, Avg = 19.46
# Geração 50: Min = 16.0, Avg = 19.77
# Geração 51: Min = 16.0, Avg = 19.51
# Geração 52: Min = 16.0, Avg = 20.04
# Geração 53: Min = 16.0, Avg = 19.7
# Geração 54: Min = 16.0, Avg = 19.15
# Geração 55: Min = 16.0, Avg = 19.05
# Geração 56: Min = 16.0, Avg = 19.29
# Geração 57: Min = 16.0, Avg = 18.83
# Geração 58: Min = 16.0, Avg = 19.33
# Geração 59: Min = 16.0, Avg = 18.79
# Geração 60: Min = 16.0, Avg = 18.51
# Geração 61: Min = 16.0, Avg = 18.59
# Geração 62: Min = 16.0, Avg = 18.57
# Geração 63: Min = 16.0, Avg = 19.42
# Geração 64: Min = 16.0, Avg = 18.3
# Geração 65: Min = 16.0, Avg = 18.89
# Geração 66: Min = 16.0, Avg = 17.83
# Geração 67: Min = 16.0, Avg = 18.44
# Geração 68: Min = 16.0, Avg = 18.71
# Geração 69: Min = 16.0, Avg = 18.79
# Geração 70: Min = 16.0, Avg = 18.34
# Geração 71: Min = 16.0, Avg = 19.64
# Geração 72: Min = 16.0, Avg = 18.75
# Geração 73: Min = 16.0, Avg = 19.72
# Geração 74: Min = 16.0, Avg = 19.82
# Geração 75: Min = 16.0, Avg = 17.88
# Geração 76: Min = 16.0, Avg = 17.98
# Geração 77: Min = 16.0, Avg = 18.79
# Geração 78: Min = 16.0, Avg = 19.53
# Geração 79: Min = 16.0, Avg = 20.34
# Geração 80: Min = 16.0, Avg = 18.64
# Geração 81: Min = 16.0, Avg = 17.67
# Geração 82: Min = 16.0, Avg = 19.34
# Geração 83: Min = 16.0, Avg = 18.83
# Geração 84: Min = 16.0, Avg = 19.63
# Geração 85: Min = 16.0, Avg = 19.79
# Geração 86: Min = 16.0, Avg = 19.73
# Geração 87: Min = 16.0, Avg = 18.75
# Geração 88: Min = 16.0, Avg = 19.61
# Geração 89: Min = 16.0, Avg = 19.27
# Geração 90: Min = 16.0, Avg = 17.7
# Geração 91: Min = 16.0, Avg = 19.09
# Geração 92: Min = 16.0, Avg = 19.28
# Geração 93: Min = 16.0, Avg = 18.82
# Geração 94: Min = 16.0, Avg = 17.78
# Geração 95: Min = 16.0, Avg = 19.2
# Geração 96: Min = 16.0, Avg = 18.56
# Geração 97: Min = 16.0, Avg = 18.46
# Geração 98: Min = 16.0, Avg = 18.22
# Geração 99: Min = 16.0, Avg = 18.85
# Geração 0: Min = 30.0, Avg = 44.61
# Geração 1: Min = 28.0, Avg = 43.36
# Geração 2: Min = 28.0, Avg = 40.04
# Geração 3: Min = 27.0, Avg = 37.8
# Geração 4: Min = 27.0, Avg = 36.23
# Geração 5: Min = 26.0, Avg = 36.36
# Geração 6: Min = 26.0, Avg = 36.02
# Geração 7: Min = 25.0, Avg = 32.62
# Geração 8: Min = 24.0, Avg = 30.83
# Geração 9: Min = 24.0, Avg = 30.44
# Geração 10: Min = 23.0, Avg = 28.73
# Geração 11: Min = 22.0, Avg = 27.72
# Geração 12: Min = 21.0, Avg = 28.45
# Geração 13: Min = 21.0, Avg = 26.68
# Geração 14: Min = 21.0, Avg = 26.47
# Geração 15: Min = 20.0, Avg = 24.84
# Geração 16: Min = 19.0, Avg = 24.77
# Geração 17: Min = 18.0, Avg = 22.57
# Geração 18: Min = 18.0, Avg = 24.79
# Geração 19: Min = 17.0, Avg = 23.5
# Geração 20: Min = 17.0, Avg = 23.97
# Geração 21: Min = 17.0, Avg = 25.19
# Geração 22: Min = 17.0, Avg = 24.82
# Geração 23: Min = 16.0, Avg = 24.94
# Geração 24: Min = 16.0, Avg = 23.77
# Geração 25: Min = 16.0, Avg = 22.04
# Geração 26: Min = 16.0, Avg = 21.16
# Geração 27: Min = 16.0, Avg = 23.18
# Geração 28: Min = 16.0, Avg = 22.35
# Geração 29: Min = 16.0, Avg = 21.93
# Geração 30: Min = 16.0, Avg = 22.02
# Geração 31: Min = 16.0, Avg = 21.89
# Geração 32: Min = 16.0, Avg = 20.46
# Geração 33: Min = 16.0, Avg = 21.07
# Geração 34: Min = 16.0, Avg = 19.84
# Geração 35: Min = 16.0, Avg = 19.41
# Geração 36: Min = 16.0, Avg = 19.55
# Geração 37: Min = 16.0, Avg = 18.54
# Geração 38: Min = 16.0, Avg = 18.48
# Geração 39: Min = 16.0, Avg = 19.46
# Geração 40: Min = 16.0, Avg = 17.75
# Geração 41: Min = 16.0, Avg = 19.38
# Geração 42: Min = 16.0, Avg = 17.53
# Geração 43: Min = 16.0, Avg = 19.08
# Geração 44: Min = 16.0, Avg = 19.25
# Geração 45: Min = 16.0, Avg = 18.56
# Geração 46: Min = 16.0, Avg = 19.33
# Geração 47: Min = 16.0, Avg = 19.13
# Geração 48: Min = 16.0, Avg = 17.87
# Geração 49: Min = 16.0, Avg = 17.81
# Geração 50: Min = 16.0, Avg = 18.95
# Geração 51: Min = 16.0, Avg = 19.26
# Geração 52: Min = 16.0, Avg = 19.02
# Geração 53: Min = 16.0, Avg = 18.86
# Geração 54: Min = 16.0, Avg = 18.19
# Geração 55: Min = 16.0, Avg = 18.38
# Geração 56: Min = 16.0, Avg = 19.26
# Geração 57: Min = 16.0, Avg = 17.92
# Geração 58: Min = 16.0, Avg = 18.22
# Geração 59: Min = 16.0, Avg = 18.94
# Geração 60: Min = 16.0, Avg = 19.48
# Geração 61: Min = 16.0, Avg = 19.46
# Geração 62: Min = 16.0, Avg = 18.47
# Geração 63: Min = 16.0, Avg = 19.08
# Geração 64: Min = 16.0, Avg = 19.96
# Geração 65: Min = 16.0, Avg = 18.08
# Geração 66: Min = 16.0, Avg = 18.76
# Geração 67: Min = 16.0, Avg = 18.65
# Geração 68: Min = 16.0, Avg = 17.89
# Geração 69: Min = 16.0, Avg = 19.93
# Geração 70: Min = 16.0, Avg = 19.96
# Geração 71: Min = 16.0, Avg = 17.11
# Geração 72: Min = 16.0, Avg = 18.49
# Geração 73: Min = 16.0, Avg = 18.73
# Geração 74: Min = 16.0, Avg = 17.67
# Geração 75: Min = 16.0, Avg = 17.23
# Geração 76: Min = 16.0, Avg = 18.14
# Geração 77: Min = 16.0, Avg = 19.43
# Geração 78: Min = 16.0, Avg = 19.07
# Geração 79: Min = 16.0, Avg = 18.32
# Geração 80: Min = 16.0, Avg = 18.81
# Geração 81: Min = 16.0, Avg = 18.33
# Geração 82: Min = 16.0, Avg = 18.24
# Geração 83: Min = 16.0, Avg = 19.15
# Geração 84: Min = 16.0, Avg = 19.34
# Geração 85: Min = 16.0, Avg = 18.78
# Geração 86: Min = 16.0, Avg = 19.29
# Geração 87: Min = 16.0, Avg = 18.71
# Geração 88: Min = 16.0, Avg = 19.25
# Geração 89: Min = 16.0, Avg = 18.85
# Geração 90: Min = 16.0, Avg = 19.01
# Geração 91: Min = 16.0, Avg = 19.43
# Geração 92: Min = 16.0, Avg = 18.86
# Geração 93: Min = 16.0, Avg = 19.1
# Geração 94: Min = 16.0, Avg = 18.2
# Geração 95: Min = 16.0, Avg = 18.8
# Geração 96: Min = 16.0, Avg = 19.12
# Geração 97: Min = 16.0, Avg = 18.82
# Geração 98: Min = 16.0, Avg = 19.58
# Geração 99: Min = 16.0, Avg = 20.3
# Geração 0: Min = 29.0, Avg = 44.96
# Geração 1: Min = 27.0, Avg = 41.06
# Geração 2: Min = 27.0, Avg = 39.6
# Geração 3: Min = 28.0, Avg = 38.09
# Geração 4: Min = 27.0, Avg = 38.55
# Geração 5: Min = 27.0, Avg = 39.33
# Geração 6: Min = 26.0, Avg = 35.52
# Geração 7: Min = 26.0, Avg = 35.72
# Geração 8: Min = 26.0, Avg = 35.79
# Geração 9: Min = 25.0, Avg = 33.83
# Geração 10: Min = 25.0, Avg = 34.55
# Geração 11: Min = 25.0, Avg = 33.99
# Geração 12: Min = 24.0, Avg = 33.95
# Geração 13: Min = 24.0, Avg = 35.16
# Geração 14: Min = 23.0, Avg = 34.49
# Geração 15: Min = 23.0, Avg = 33.46
# Geração 16: Min = 22.0, Avg = 34.67
# Geração 17: Min = 21.0, Avg = 33.83
# Geração 18: Min = 20.0, Avg = 33.64
# Geração 19: Min = 20.0, Avg = 32.29
# Geração 20: Min = 19.0, Avg = 32.81
# Geração 21: Min = 18.0, Avg = 31.82
# Geração 22: Min = 17.0, Avg = 29.21
# Geração 23: Min = 17.0, Avg = 29.0
# Geração 24: Min = 17.0, Avg = 27.84
# Geração 25: Min = 16.0, Avg = 23.57
# Geração 26: Min = 16.0, Avg = 21.2
# Geração 27: Min = 16.0, Avg = 20.5
# Geração 28: Min = 16.0, Avg = 19.78
# Geração 29: Min = 16.0, Avg = 18.34
# Geração 30: Min = 16.0, Avg = 19.14
# Geração 31: Min = 16.0, Avg = 19.02
# Geração 32: Min = 16.0, Avg = 19.83
# Geração 33: Min = 16.0, Avg = 18.36
# Geração 34: Min = 16.0, Avg = 19.31
# Geração 35: Min = 16.0, Avg = 18.95
# Geração 36: Min = 16.0, Avg = 18.61
# Geração 37: Min = 16.0, Avg = 18.95
# Geração 38: Min = 16.0, Avg = 18.92
# Geração 39: Min = 16.0, Avg = 18.48
# Geração 40: Min = 16.0, Avg = 17.63
# Geração 41: Min = 16.0, Avg = 19.25
# Geração 42: Min = 16.0, Avg = 17.86
# Geração 43: Min = 16.0, Avg = 18.51
# Geração 44: Min = 16.0, Avg = 19.23
# Geração 45: Min = 16.0, Avg = 18.36
# Geração 46: Min = 16.0, Avg = 17.91
# Geração 47: Min = 16.0, Avg = 18.8
# Geração 48: Min = 16.0, Avg = 19.76
# Geração 49: Min = 16.0, Avg = 19.1
# Geração 50: Min = 16.0, Avg = 18.02
# Geração 51: Min = 16.0, Avg = 18.44
# Geração 52: Min = 16.0, Avg = 18.53
# Geração 53: Min = 16.0, Avg = 17.81
# Geração 54: Min = 16.0, Avg = 17.84
# Geração 55: Min = 16.0, Avg = 17.86
# Geração 56: Min = 16.0, Avg = 18.47
# Geração 57: Min = 16.0, Avg = 19.86
# Geração 58: Min = 16.0, Avg = 18.5
# Geração 59: Min = 16.0, Avg = 18.95
# Geração 60: Min = 16.0, Avg = 18.23
# Geração 61: Min = 16.0, Avg = 18.32
# Geração 62: Min = 16.0, Avg = 18.35
# Geração 63: Min = 16.0, Avg = 17.87
# Geração 64: Min = 16.0, Avg = 19.01
# Geração 65: Min = 16.0, Avg = 18.5
# Geração 66: Min = 16.0, Avg = 18.82
# Geração 67: Min = 16.0, Avg = 19.13
# Geração 68: Min = 16.0, Avg = 19.39
# Geração 69: Min = 16.0, Avg = 18.16
# Geração 70: Min = 16.0, Avg = 17.92
# Geração 71: Min = 16.0, Avg = 18.0
# Geração 72: Min = 16.0, Avg = 18.2
# Geração 73: Min = 16.0, Avg = 18.46
# Geração 74: Min = 16.0, Avg = 18.8
# Geração 75: Min = 16.0, Avg = 18.93
# Geração 76: Min = 16.0, Avg = 19.98
# Geração 77: Min = 16.0, Avg = 19.28
# Geração 78: Min = 16.0, Avg = 20.08
# Geração 79: Min = 16.0, Avg = 19.38
# Geração 80: Min = 16.0, Avg = 18.48
# Geração 81: Min = 16.0, Avg = 18.84
# Geração 82: Min = 16.0, Avg = 17.75
# Geração 83: Min = 16.0, Avg = 18.13
# Geração 84: Min = 16.0, Avg = 17.93
# Geração 85: Min = 16.0, Avg = 19.5
# Geração 86: Min = 16.0, Avg = 18.94
# Geração 87: Min = 16.0, Avg = 17.31
# Geração 88: Min = 16.0, Avg = 18.7
# Geração 89: Min = 16.0, Avg = 17.94
# Geração 90: Min = 16.0, Avg = 19.29
# Geração 91: Min = 16.0, Avg = 17.99
# Geração 92: Min = 16.0, Avg = 19.34
# Geração 93: Min = 16.0, Avg = 20.08
# Geração 94: Min = 16.0, Avg = 20.2
# Geração 95: Min = 16.0, Avg = 19.96
# Geração 96: Min = 16.0, Avg = 19.0
# Geração 97: Min = 16.0, Avg = 19.35
# Geração 98: Min = 16.0, Avg = 19.32
# Geração 99: Min = 16.0, Avg = 19.41
# Média do número de bins: 16.1
# Melhor solução: [22, 45, 38, 4, 45, 35, 38, 41, 22, 41, 41, 27, 6, 39, 4, 6, 42, 27, 38, 31, 3, 39, 42, 3, 3, 30, 18, 3, 30, 44, 41, 35, 45, 30, 18, 31, 42, 6, 18, 44, 27, 39, 44, 22, 49, 45, 42, 4, 44, 4]
# Valor total: 16
# Peso total: 1452
# tamanho da Solução: 50
